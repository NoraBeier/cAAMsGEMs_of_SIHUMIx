# %%
import cobra
from cobra import Model, Reaction, Metabolite
from cobra.flux_analysis import flux_variability_analysis
from cobra.io import load_model
from cobra.io import load_json_model, save_json_model, load_matlab_model, save_matlab_model, read_sbml_model, write_sbml_model
import logging
import pandas
import memote

# %%
upos = read_sbml_model("/homes/brauerei/natasha/miniconda3/lib/python3.9/site-packages/carveme/data/generated/universe_grampos.xml")

# %%
#Changing model id so I know it's my stuff
upos.id = "grampos_universeN"

# %%
## According to wikipedia (with referenced papers), gramm positive bacteria DO have a periplasm. 
## Although it is much smaller than the one present in gramm negative bacteria, it is still there
## During my attempt to remove the periplasm compartment, I've seen reactions and metabolites unique to gramm positive bacteria present in the periplasm.
## Given all of that, I've decided not to remove the periplasm compartment.
## Wiki reference: https://en.wikipedia.org/wiki/Periplasm

# %%
#Adding essential metabolites in Biomass
# Number obtained based on the amount of the other vitamins/co-factors present in the Growth reaction. Is it right?
upos.reactions.get_by_id("Growth").add_metabolites({upos.metabolites.get_by_id("fmn_c"): 0.000223})

# %%
#Fixing masses
#Evaluated manualy. Values obtained from BiGG, KEGG, ModelSEED, and CHEBI
upos.metabolites.get_by_id("12d3k5m_c").formula = "C6H10O3S"
upos.metabolites.get_by_id("2mb_p_c").formula = "C5H9O5P"
upos.metabolites.get_by_id("2mpdhl_c").formula = "C12H23NO2S2"
upos.metabolites.get_by_id("23dappa_c").formula = "C3H9N2O2"
upos.metabolites.get_by_id("23dappa_e").formula = "C3H9N2O2"
upos.metabolites.get_by_id("23dappa_p").formula = "C3H9N2O2"
upos.metabolites.get_by_id("23dhb_c").formula = "C7H6O4"
upos.metabolites.get_by_id("23dhbzs_c").formula = "C10H11NO6"
upos.metabolites.get_by_id("23dhbzs2_c").formula = "C20H20N2O11"
upos.metabolites.get_by_id("23dhbzs3_c").formula = "C30H29N3O16"
upos.metabolites.get_by_id("23dhbzs3_e").formula = "C30H29N3O16"
upos.metabolites.get_by_id("23dhbzs3_p").formula = "C30H29N3O16"
upos.metabolites.get_by_id("34dhsa_c").formula = "C19H24O4"
upos.metabolites.get_by_id("3h4atb_c").formula = "C6H9O4S"
upos.metabolites.get_by_id("3h4atb_e").formula = "C6H9O4S"
upos.metabolites.get_by_id("3h4atb_p").formula = "C6H9O4S"
upos.metabolites.get_by_id("3h4atbcoa_c").formula = "C27H40N7O19P3S2"
upos.metabolites.get_by_id("3h6athcoa_c").formula = "C29H44N7O19P3S2"
upos.metabolites.get_by_id("3hcmrs7eACP_c").formula = "C25H45N2O9PRS"
upos.metabolites.get_by_id("3hdd6coa_c").formula = "C33H52N7O18P3S"
upos.metabolites.get_by_id("3hddecACP_c").formula = "C23H43N2O9PRS"
upos.metabolites.get_by_id("3hdecACP_c").formula = "C21H39N2O9PRS"
upos.metabolites.get_by_id("3hhd58coa_c").formula = "C35H54N7O18P3S"
upos.metabolites.get_by_id("3hhd710coa_c").formula = "C37H58N7O18P3S"
upos.metabolites.get_by_id("3hddccoa_c").formula = "C33H52N7O18P3S"
upos.metabolites.get_by_id("3hlnlccoa_c").formula = "C39H62N7O18P3S"
upos.metabolites.get_by_id("3hmrsACP_c").formula = "C25H47N2O9PRS"
upos.metabolites.get_by_id("3hnonacoa_c").formula = "C30H48N7O18P3S"
upos.metabolites.get_by_id("3hoctACP_c").formula = "C19H35N2O9PRS"
upos.metabolites.get_by_id("3hpdecacoa_c").formula = "C37H54N7O18P3S"
upos.metabolites.get_by_id("3hphpcoa_c").formula = "C34H48N7O18P3S"
upos.metabolites.get_by_id("3hphxacoa_c").formula = "C33H46N7O18P3S"
upos.metabolites.get_by_id("3hpnonacoa_c").formula = "C36H52N7O18P3S"
upos.metabolites.get_by_id("3hpptcoa_c").formula = "C32H44N7O18P3S"
upos.metabolites.get_by_id("3hptslacoa_c").formula = "C39H64N7O18P3S"
upos.metabolites.get_by_id("3hsa_c").formula = "C19H24O3"
upos.metabolites.get_by_id("3o6athcoa_c").formula = "C29H42N7O19P3S2"
upos.metabolites.get_by_id("3odd6coa_c").formula = "C33H50N7O18P3S"
upos.metabolites.get_by_id("3oddccoa_c").formula = "C33H50N7O18P3S"
upos.metabolites.get_by_id("3ohd58coa_c").formula = "C35H52N7O18P3S"
upos.metabolites.get_by_id("3ohd710coa_c").formula = "C37H56N7O18P3S"
upos.metabolites.get_by_id("3olnlccoa_c").formula = "C39H60N7O18P3S"
upos.metabolites.get_by_id("3ononacoa_c").formula = "C30H46N7O18P3S"
upos.metabolites.get_by_id("3opcoa_c").formula = "C24H34N7O18P3S"
upos.metabolites.get_by_id("3opdecacoa_c").formula = "C37H52N7O18P3S"
upos.metabolites.get_by_id("3ophpcoa_c").formula = "C34H46N7O18P3S"
upos.metabolites.get_by_id("3ophxacoa_c").formula = "C33H44N7O18P3S"
upos.metabolites.get_by_id("3opnonacoa_c").formula = "C36H50N7O18P3S"
upos.metabolites.get_by_id("3opoctacoa_c").formula = "C35H48N7O18P3S"
upos.metabolites.get_by_id("3opptcoa_c").formula = "C32H42N7O18P3S"
upos.metabolites.get_by_id("3optslacoa_c").formula = "C39H62N7O18P3S"
upos.metabolites.get_by_id("3otdccoa_c").formula = "C35H54N7O18P3S"
upos.metabolites.get_by_id("3hpoctacoa_c").formula = "C35H50N7O18P3S"
upos.metabolites.get_by_id("49dsha_c").formula = "C19H24O6"
upos.metabolites.get_by_id("4atb2coa_c").formula = "C27H38N7O18P3S2"
upos.metabolites.get_by_id("4atbcoa_c").formula = "C27H40N7O18P3S2"
upos.metabolites.get_by_id("5ohhipcoa_c").formula = "C34H54N7O19P3S"
upos.metabolites.get_by_id("3htdccoa_c").formula = "C35H56N7O18P3S"
upos.metabolites.get_by_id("5ohhip_c").formula = "C13H20O4"
upos.metabolites.get_by_id("6atha_e").formula = "C8H13O3S"
upos.metabolites.get_by_id("6atha_p").formula = "C8H13O3S"
upos.metabolites.get_by_id("6athcoa_c").formula = "C29H44N7O18P3S2"
upos.metabolites.get_by_id("6ath2coa_c").formula = "C29H42N7O18P3S2"
upos.metabolites.get_by_id("9ohadd_c").formula = "C19H24O3"
upos.metabolites.get_by_id("acadl_c").formula = "C12H16N5O8P"
upos.metabolites.get_by_id("ACP_c").formula = "C11H21N2O7PRS"
upos.metabolites.get_by_id("airs_c").formula = 'C8H13N3O4'
upos.metabolites.get_by_id("airs_e").formula = 'C8H13N3O4'
upos.metabolites.get_by_id("airs_p").formula = 'C8H13N3O4'
upos.metabolites.get_by_id("andrstndn_c").formula = "C19H26O2"
upos.metabolites.get_by_id("andrs14dn317dn_c").formula = "C19H24O2"
upos.metabolites.get_by_id("apoACP_c").formula = "HOR"
upos.metabolites.get_by_id("arachACP_c").formula = "C31H59N2O8PRS"
upos.metabolites.get_by_id("benzcoa_c").formula = 'C28H36N7O17P3S'
upos.metabolites.get_by_id("bmn_c").formula = "C10H10N2O2"
upos.metabolites.get_by_id("bmn_e").formula = "C10H10N2O2"
upos.metabolites.get_by_id("cchol_c").formula = "C27H42O3"
upos.metabolites.get_by_id("cholc3coa_c").formula = "C43H66N7O18P3S"
upos.metabolites.get_by_id("cholc5coa_c").formula = "C45H70N7O18P3S"
upos.metabolites.get_by_id("cholc8coa_c").formula = "C48H76N7O18P3S"
upos.metabolites.get_by_id("cholenec3coa_c").formula = "C43H64N7O18P3S"
upos.metabolites.get_by_id("cholenec5coa_c").formula = "C45H68N7O18P3S"
upos.metabolites.get_by_id("cholenec8coa_c").formula = "C48H74N7O18P3S"
upos.metabolites.get_by_id("citdae_c").formula = "C8H14N2O7"
upos.metabolites.get_by_id("citdapp_c").formula = "C9H14N2O9"
upos.metabolites.get_by_id("d23hb_e").formula = "C7H7O4"
upos.metabolites.get_by_id("db4p_c").formula = 'C4H7O6P'
upos.metabolites.get_by_id("dcaACP_c").formula = "C21H39N2O8PRS"
upos.metabolites.get_by_id("dd6_2_coa_c").formula = "C33H50N7O17P3S"
upos.metabolites.get_by_id("dd_3_6_coa_c").formula = "C33H50N7O17P3S"
upos.metabolites.get_by_id("ddcaACP_c").formula = "C23H43N2O8PRS"
upos.metabolites.get_by_id("decoa_c").formula = 'C31H48N7O17P3S'
upos.metabolites.get_by_id("dde2coa_c").formula = "C33H50N7O17P3S"
upos.metabolites.get_by_id("ddecoa_c").formula = "C33H52N7O17P3S"
upos.metabolites.get_by_id("dec4coa_c").formula = "C31H48N7O17P3S"
upos.metabolites.get_by_id("dmlz_c").formula = 'C13H18N4O6'
upos.metabolites.get_by_id("dmso2_c").formula = "C2H6O2S"
upos.metabolites.get_by_id("dmso2_e").formula = "C2H6O2S"
upos.metabolites.get_by_id("dmso2_p").formula = "C2H6O2S"
upos.metabolites.get_by_id("enter_c").formula = 'C30H27N3O15'
upos.metabolites.get_by_id("enter_e").formula = 'C30H27N3O15'
upos.metabolites.get_by_id("enter_p").formula = 'C30H27N3O15'
upos.metabolites.get_by_id("entermg_c").formula = 'C36H37N3O20'
upos.metabolites.get_by_id("fad_c").formula = 'C27H31N9O15P2'
upos.metabolites.get_by_id("fad_e").formula = 'C27H31N9O15P2'
upos.metabolites.get_by_id("fad_p").formula = 'C27H31N9O15P2'
upos.metabolites.get_by_id("fadh2_c").formula = 'C27H33N9O15P2'
upos.metabolites.get_by_id("fbac_kt_c").formula = "C27H47N10O15"
upos.metabolites.get_by_id("fbac_kt_p").formula = "C27H47N10O15"
upos.metabolites.get_by_id("fcmcbtt_c").formula = 'C33FeH48N5O13'
upos.metabolites.get_by_id("fcmcbtt_e").formula = 'C33FeH48N5O13'
upos.metabolites.get_by_id("fcmcbtt_p").formula = 'C33FeH48N5O13'
upos.metabolites.get_by_id("fdxo_2_2_c").formula = "Fe2S2"
upos.metabolites.get_by_id("fe3dhbzs_c").formula = "C10H11NO6Fe"
upos.metabolites.get_by_id("fe3dhbzs_e").formula = "C10H11NO6Fe"
upos.metabolites.get_by_id("fe3dhbzs_p").formula = "C10H11NO6Fe"
upos.metabolites.get_by_id("fe3dhbzs3_c").formula = "C30H29N3O16Fe"
upos.metabolites.get_by_id("fe3dhbzs3_e").formula = "C30H29N3O16Fe"
upos.metabolites.get_by_id("fe3dhbzs3_p").formula = "C30H29N3O16Fe"
upos.metabolites.get_by_id("fe3mcbtt_c").formula = "C43H71N5O10Fe"
upos.metabolites.get_by_id("fe3mcbtt_e").formula = "C43H71N5O10Fe"
upos.metabolites.get_by_id("fe3mcbtt_p").formula = "C43H71N5O10Fe"
upos.metabolites.get_by_id("fe3pyovd_kt_e").formula = "C27H47FeN10O15"
upos.metabolites.get_by_id("fe3pyovd_kt_p").formula = "C27H47FeN10O15"
upos.metabolites.get_by_id("feenter_c").formula = 'C30H27FeN3O15'
upos.metabolites.get_by_id("feenter_e").formula = 'C30H27FeN3O15'
upos.metabolites.get_by_id("feenter_p").formula = 'C30H27FeN3O15'
upos.metabolites.get_by_id("ficytb_c").formula = "C42H53FeN8O6S2"
upos.metabolites.get_by_id("ficytc_c").formula = "C42H52FeN8O6S2"
upos.metabolites.get_by_id("ficytC_c").formula = "C42H54FeN8O6S2"
upos.metabolites.get_by_id("fmcbtt_c").formula = "C43H71N5O10Fe"
upos.metabolites.get_by_id("fmn_c").formula = 'C17H19N4O9P'
upos.metabolites.get_by_id("fmn_e").formula = 'C17H19N4O9P'
upos.metabolites.get_by_id("fmn_p").formula = 'C17H19N4O9P'
upos.metabolites.get_by_id("fmnRD_c").formula = 'C17H21N4O9P'
upos.metabolites.get_by_id("fmnh2_c").formula = "C17H21N4O9P"
upos.metabolites.get_by_id("focytc_c").formula = "C42H53FeN8O6S2"
upos.metabolites.get_by_id("focytC_c").formula = "C42H54FeN8O6S2"
upos.metabolites.get_by_id("glycol_e").formula = "C2H6O2"
upos.metabolites.get_by_id("glycol_p").formula = "C2H6O2"
upos.metabolites.get_by_id("gly_cys_c").formula = "C5H10N2O3S"
upos.metabolites.get_by_id("gly_cys_e").formula = "C5H10N2O3S"
upos.metabolites.get_by_id("gly_leu_e").formula = "C8H16N2O3"
upos.metabolites.get_by_id("gly_leu_c").formula = "C8H16N2O3"
upos.metabolites.get_by_id("gly_phe_e").formula = "C11H14N2O3"
upos.metabolites.get_by_id("gly_phe_c").formula = "C11H14N2O3"
upos.metabolites.get_by_id("gly_tyr_c").formula = "C11H14N2O4"
upos.metabolites.get_by_id("gly_tyr_e").formula = "C11H14N2O4"
upos.metabolites.get_by_id("hchol_c").formula = "C27H44O2"
upos.metabolites.get_by_id("hcholc3coa_c").formula = "C43H66N7O19P3S"
upos.metabolites.get_by_id("hcholc5coa_c").formula = "C45H70N7O19P3S"
upos.metabolites.get_by_id("hcholc8coa_c").formula = "C48H76N7O19P3S"
upos.metabolites.get_by_id("hd_7_10_coa_c").formula = "C37H58N7O17P3S"
upos.metabolites.get_by_id("hd710_2_coa_c").formula = "C37H56N7O17P3S"
upos.metabolites.get_by_id("hdd4coa_c").formula = "C37H60N7O17P3S"
upos.metabolites.get_by_id("hdeACP_c").formula = "C27H49N2O8PRS"
upos.metabolites.get_by_id("hia_c").formula = "C11H20O4"
upos.metabolites.get_by_id("hia_e").formula = "C11H20O4"
upos.metabolites.get_by_id("hip_c").formula = "C13H18O4"
upos.metabolites.get_by_id("hipcoa_c").formula = "C34H52N7O19P3S"
upos.metabolites.get_by_id("hipecoa_c").formula = "C34H52N7O19P3S"
upos.metabolites.get_by_id("hipocoa_c").formula = "C34H52N7O20P3S"
upos.metabolites.get_by_id("hipohcoa_c").formula = "C34H54N7O20P3S"
upos.metabolites.get_by_id("hpta_c").formula = "C7H13O2"
upos.metabolites.get_by_id("hpta_e").formula = "C7H13O2"
upos.metabolites.get_by_id("hpta_p").formula = "C7H13O2"
upos.metabolites.get_by_id("hptcoa_c").formula = "C28H44N7O17P3S"
upos.metabolites.get_by_id("ib_p_c").formula = "C4H7O5P"
upos.metabolites.get_by_id("istfrnB_e").formula = "C19FeH23N2O19"
upos.metabolites.get_by_id("ldpcde_c").formula = "C14H19N2O14"
upos.metabolites.get_by_id("leu__D_c").formula = 'C6H13NO2'
upos.metabolites.get_by_id("leu__D_e").formula = 'C6H13NO2'
upos.metabolites.get_by_id("leu__D_p").formula = 'C6H13NO2'
upos.metabolites.get_by_id("lipoate_c").formula = "C8H14O2S2"
upos.metabolites.get_by_id("lipoate_e").formula = "C8H14O2S2"
upos.metabolites.get_by_id("lipoate_p").formula = "C8H14O2S2"
upos.metabolites.get_by_id("lnlc2coa_c").formula = "C39H60N7O17P3S"
upos.metabolites.get_by_id("m2butp_c").formula = "C5H10O5P"
upos.metabolites.get_by_id("m2but_c").formula = "C5H10O2"
upos.metabolites.get_by_id("m2but_e").formula = "C5H10O2"
upos.metabolites.get_by_id("mcbtt_c").formula = "C43H71N5O10"
upos.metabolites.get_by_id("mcbtt_e").formula = "C43H71N5O10"
upos.metabolites.get_by_id("mcbtt_p").formula = "C43H71N5O10"
upos.metabolites.get_by_id("mql8_c").formula = "C51H74O2"
upos.metabolites.get_by_id("myrsACP_c").formula = "C25H47N2O8PRS"
upos.metabolites.get_by_id("nacg_c").formula = 'C8H13N2O6'
upos.metabolites.get_by_id("Nforglu_c").formula = 'C6H7NO5'
upos.metabolites.get_by_id("nona2coa_c").formula = "C30H46N7O17P3S"
upos.metabolites.get_by_id("ocACP_c").formula = "C19H35N2O8PRS"
upos.metabolites.get_by_id("ocdcaACP_c").formula = "C29H55N2O8PRS"
upos.metabolites.get_by_id("ochol_c").formula = "C27H42O2"
upos.metabolites.get_by_id("ocholc5coa_c").formula = "C45H68N7O19P3S"
upos.metabolites.get_by_id("ocholc8coa_c").formula = "C48H74N7O19P3S"
upos.metabolites.get_by_id("octeACP_c").formula = "C29H53N2O8PRS"
upos.metabolites.get_by_id("palmACP_c").formula = "C27H51N2O8PRS"
upos.metabolites.get_by_id("pbcoa_c").formula = "C31H42N7O17P3S"
upos.metabolites.get_by_id("pdca2coa_c").formula = "C37H52N7O17P3S"
upos.metabolites.get_by_id("pdcacoa_c").formula = "C37H54N7O17P3S"
upos.metabolites.get_by_id("pdima_c").formula = "C96H190O5"
upos.metabolites.get_by_id("pdima_e").formula = "C96H190O5"
upos.metabolites.get_by_id("pea_c").formula = "C8H10O"
upos.metabolites.get_by_id("pea_e").formula = "C8H10O"
upos.metabolites.get_by_id("pea_p").formula = "C8H10O"
upos.metabolites.get_by_id("phdca_c").formula = "C23H37O3"
upos.metabolites.get_by_id("phdca_e").formula = "C23H37O3"
upos.metabolites.get_by_id("phdcaACP_c").formula = "C34H57N2O9PRS"
upos.metabolites.get_by_id("phdcacoa_c").formula = "C44H68N7O18P3S"
upos.metabolites.get_by_id("phe__D_c").formula = "C9H11NO2"
upos.metabolites.get_by_id("phe__D_e").formula = "C9H11NO2"
upos.metabolites.get_by_id("phe__D_p").formula = "C9H11NO2"
upos.metabolites.get_by_id("phedca_e").formula = "C16H23O2"
upos.metabolites.get_by_id("phedca_p").formula = "C16H23O2"
upos.metabolites.get_by_id("phehpa_e").formula = "C13H17O2"
upos.metabolites.get_by_id("phehpa_p").formula = "C13H17O2"
upos.metabolites.get_by_id("phehxa_e").formula = "C12H15O2"
upos.metabolites.get_by_id("phehxa_p").formula = "C12H15O2"
upos.metabolites.get_by_id("phenona_e").formula = "C15H21O2"
upos.metabolites.get_by_id("phenona_p").formula = "C15H21O2"
upos.metabolites.get_by_id("pheocta_e").formula = "C14H19O2"
upos.metabolites.get_by_id("pheocta_p").formula = "C14H19O2"
upos.metabolites.get_by_id("phept_e").formula = "C11H13O2"
upos.metabolites.get_by_id("phept_p").formula = "C11H13O2"
upos.metabolites.get_by_id("phpcoa_c").formula = "C34H48N7O17P3S"
upos.metabolites.get_by_id("php2coa_c").formula = "C34H46N7O17P3S"
upos.metabolites.get_by_id("phppcoa_c").formula = "C30H40N7O17P3S"
upos.metabolites.get_by_id("phthdl_c").formula = "C31H62O3"
upos.metabolites.get_by_id("phthiocerol_c").formula = "C32H66O3"
upos.metabolites.get_by_id("phxa2coa_c").formula = "C33H44N7O17P3S"
upos.metabolites.get_by_id("pnona2coa_c").formula = "C36H50N7O17P3S"
upos.metabolites.get_by_id("phxacoa_c").formula = "C33H46N7O17P3S"
upos.metabolites.get_by_id("pnonacoa_c").formula = "C36H52N7O17P3S"
upos.metabolites.get_by_id("poctacoa_c").formula = "C35H50N7O17P3S"
upos.metabolites.get_by_id("pocta2coa_c").formula = "C35H48N7O17P3S"
upos.metabolites.get_by_id("ppdima_c").formula = "C99H188O6"
upos.metabolites.get_by_id("ppdima_e").formula = "C99H188O6"
upos.metabolites.get_by_id("pphthdl_c").formula = "C34H60O4"
upos.metabolites.get_by_id("pphthiocerol_c").formula = "C35H64O4"
upos.metabolites.get_by_id("ppt2coa_c").formula = "C32H42N7O17P3S"
upos.metabolites.get_by_id("pptcoa_c").formula = "C32H44N7O17P3S"
upos.metabolites.get_by_id("pqq_c").formula = "C14H3N2O8"
upos.metabolites.get_by_id("pqq_p").formula = "C14H3N2O8"
upos.metabolites.get_by_id("pqqh2_c").formula = "C14H5N2O8"
upos.metabolites.get_by_id("pqqh2_p").formula = "C14H5N2O8"
upos.metabolites.get_by_id("prephth_c").formula = "C32H61O5"
upos.metabolites.get_by_id("prephthACP_c").formula = "C43H81N2O11PRS"
upos.metabolites.get_by_id("prephthcoa_c").formula = "C53H92N7O20P3S"
upos.metabolites.get_by_id("prepphth_c").formula = "C35H59O6"
upos.metabolites.get_by_id("prepphthACP_c").formula = "C46H79N2O12PRS"
upos.metabolites.get_by_id("pro__D_c").formula = "C5H9NO2"
upos.metabolites.get_by_id("pro__D_e").formula = "C5H9NO2"
upos.metabolites.get_by_id("pro__D_p").formula = "C5H9NO2"
upos.metabolites.get_by_id("pser_c").formula = "C3H8NO6P"
upos.metabolites.get_by_id("ptsla_e").formula = "C18H33O2"
upos.metabolites.get_by_id("ptsla_p").formula = "C18H33O2"
upos.metabolites.get_by_id("ptslacoa_c").formula = "C39H64N7O17P3S"
upos.metabolites.get_by_id("ptsla2coa_c").formula = "C39H62N7O17P3S"
upos.metabolites.get_by_id("pvdiq_p").formula = "C27H47N10O15"
upos.metabolites.get_by_id("pyovd_kt_e").formula = "C27H47N10O15"
upos.metabolites.get_by_id("pyovd_kt_p").formula = "C27H47N10O15"
upos.metabolites.get_by_id("R_3h4atba_c").formula = "C6H9O4S"
upos.metabolites.get_by_id("R_3h4atba_e").formula = "C6H9O4S"
upos.metabolites.get_by_id("R_3h4atba_p").formula = "C6H9O4S"
upos.metabolites.get_by_id("R_3h4atbcoa_c").formula = "C27H40N7O19P3S2"
upos.metabolites.get_by_id("R_3h6atha_c").formula = "C8H13O4S"
upos.metabolites.get_by_id("R_3h6atha_e").formula = "C8H13O4S"
upos.metabolites.get_by_id("R_3h6atha_p").formula = "C8H13O4S"
upos.metabolites.get_by_id("R_3h6athcoa_c").formula = "C29H44N7O19P3S2"
upos.metabolites.get_by_id("R_3hcddec5ecoa_c").formula = "C33H52N7O18P3S"
upos.metabolites.get_by_id("R_3hcmrs7e_c").formula = "C14H25O3"
upos.metabolites.get_by_id("R_3hcmrs7e_e").formula = "C14H25O3"
upos.metabolites.get_by_id("R_3hcmrs7e_p").formula = "C14H25O3"
upos.metabolites.get_by_id("R_3hcmrs7ecoa_c").formula = "C35H56N7O18P3S"
upos.metabolites.get_by_id("R_3hdd5ea_c").formula = "C12H21O3"
upos.metabolites.get_by_id("R_3hdd5ea_e").formula = "C12H21O3"
upos.metabolites.get_by_id("R_3hdd5ea_p").formula = "C12H21O3"
upos.metabolites.get_by_id("R_3hdd6coa_c").formula = "C33H52N7O18P3S"
upos.metabolites.get_by_id("R_3hdd6e_c").formula = "C12H21O3"
upos.metabolites.get_by_id("R_3hdd6e_e").formula = "C12H21O3"
upos.metabolites.get_by_id("R_3hdd6e_p").formula = "C12H21O3"
upos.metabolites.get_by_id("R_3hnonaa_c").formula = "C9H17O3"
upos.metabolites.get_by_id("R_3hnonaa_e").formula = "C9H17O3"
upos.metabolites.get_by_id("R_3hnonaa_p").formula = "C9H17O3"
upos.metabolites.get_by_id("R_3hnonacoa_c").formula = "C30H48N7O18P3S"
upos.metabolites.get_by_id("R_3hpdeca_c").formula = "C16H23O3"
upos.metabolites.get_by_id("R_3hpdeca_e").formula = "C16H23O3"
upos.metabolites.get_by_id("R_3hpdeca_p").formula = "C16H23O3"
upos.metabolites.get_by_id("R_3hpdecacoa_c").formula = "C37H54N7O18P3S"
upos.metabolites.get_by_id("R_3hphpa_c").formula = "C13H17O3"
upos.metabolites.get_by_id("R_3hphpa_e").formula = "C13H17O3"
upos.metabolites.get_by_id("R_3hphpa_p").formula = "C13H17O3"
upos.metabolites.get_by_id("R_3hphpcoa_c").formula = "C34H48N7O18P3S"
upos.metabolites.get_by_id("R_3hphxa_c").formula = "C12H15O3"
upos.metabolites.get_by_id("R_3hphxa_e").formula = "C12H15O3"
upos.metabolites.get_by_id("R_3hphxa_p").formula = "C12H15O3"
upos.metabolites.get_by_id("R_3hphxacoa_c").formula = "C33H46N7O18P3S"
upos.metabolites.get_by_id("R_3hpnona_c").formula = "C15H21O3"
upos.metabolites.get_by_id("R_3hpnona_e").formula = "C15H21O3"
upos.metabolites.get_by_id("R_3hpnona_p").formula = "C15H21O3"
upos.metabolites.get_by_id("R_3hpnonacoa_c").formula = "C36H52N7O18P3S"
upos.metabolites.get_by_id("R_3hpocta_c").formula = "C14H19O3"
upos.metabolites.get_by_id("R_3hpocta_e").formula = "C14H19O3"
upos.metabolites.get_by_id("R_3hpocta_p").formula = "C14H19O3"
upos.metabolites.get_by_id("R_3hpoctacoa_c").formula = "C35H50N7O18P3S"
upos.metabolites.get_by_id("R_3hppta_c").formula = "C11H13O3"
upos.metabolites.get_by_id("R_3hppta_e").formula = "C11H13O3"
upos.metabolites.get_by_id("R_3hppta_p").formula = "C11H13O3"
upos.metabolites.get_by_id("R_3hpptcoa_c").formula = "C32H44N7O18P3S"
upos.metabolites.get_by_id("R_3htd58e_c").formula = "C14H23O3"
upos.metabolites.get_by_id("R_3htd58e_e").formula = "C14H23O3"
upos.metabolites.get_by_id("R_3htd58e_p").formula = "C14H23O3"
upos.metabolites.get_by_id("R_3htd58coa_c").formula = "C35H54N7O18P3S"
upos.metabolites.get_by_id("rbflvrd_c").formula = 'C17H22N4O6'
upos.metabolites.get_by_id("ribflv_c").formula = 'C17H20N4O6'
upos.metabolites.get_by_id("ribflv_e").formula = 'C17H20N4O6'  
upos.metabolites.get_by_id("salchs1_c").formula = "C26H30N2O16"
upos.metabolites.get_by_id("salchs2_c").formula = "C42H42N3O26"
upos.metabolites.get_by_id("salchs2_e").formula = "C42H42N3O26"
upos.metabolites.get_by_id("salchs2_p").formula = "C42H42N3O26"
upos.metabolites.get_by_id("salchs2fe_c").formula = "C42H42N3O26Fe"
upos.metabolites.get_by_id("salchs2fe_e").formula = "C42H42N3O26Fe"
upos.metabolites.get_by_id("salchs2fe_p").formula = "C42H42N3O26Fe"
upos.metabolites.get_by_id("salchs4_c").formula = "C42H42N3O25"
upos.metabolites.get_by_id("salchs4_e").formula = "C42H42N3O25"
upos.metabolites.get_by_id("salchs4_p").formula = "C42H42N3O25"
upos.metabolites.get_by_id("salchs4fe_c").formula = "C42FeH42N3O25"
upos.metabolites.get_by_id("salchs4fe_e").formula = "C42FeH42N3O25"
upos.metabolites.get_by_id("salchs4fe_p").formula = "C42FeH42N3O25"
upos.metabolites.get_by_id("salchsx_c").formula = "C16H21NO11"
upos.metabolites.get_by_id("salchsx_e").formula = "C16H21NO11"
upos.metabolites.get_by_id("salchsx_p").formula = "C16H21NO11"
upos.metabolites.get_by_id("selhcys_c").formula = "C4H9NO2Se"
upos.metabolites.get_by_id("srb__L_c").formula = "C6H12O6"
upos.metabolites.get_by_id("srb__L_e").formula = "C6H12O6"
upos.metabolites.get_by_id("stfrnB_c").formula = "C19H23N2O19"
upos.metabolites.get_by_id("stfrnB_e").formula = "C19H23N2O19"
upos.metabolites.get_by_id("t3c7mrseACP_c").formula = "C25H43N2O8PRS"
upos.metabolites.get_by_id("tag1p__D_c").formula = "C6H11O9P"
upos.metabolites.get_by_id("tag__D_e").formula = "C6H12O6"
upos.metabolites.get_by_id("tag__D_p").formula = "C6H12O6"
upos.metabolites.get_by_id("td_5_8_coa_c").formula = "C35H54N7O17P3S"
upos.metabolites.get_by_id("td58_2_coa_c").formula = "C35H52N7O17P3S"
upos.metabolites.get_by_id("tddec2eACP_c").formula = "C23H41N2O8PRS"
upos.metabolites.get_by_id("tde2coa_c").formula = "C35H54N7O17P3S"
upos.metabolites.get_by_id("tdeACP_c").formula = "C25H45N2O8PRS"
upos.metabolites.get_by_id("tdec2eACP_c").formula = "C21H37N2O8PRS"
upos.metabolites.get_by_id("tmrs2eACP_c").formula = "C25H45N2O8PRS"
upos.metabolites.get_by_id("toct2eACP_c").formula = "C19H33N2O8PRS"
upos.metabolites.get_by_id("trdox_c").formula = "C10H12N4O4S2R4"
upos.metabolites.get_by_id("trdrd_c").formula = "C10H14N4O4S2R4"
upos.metabolites.get_by_id("tton_e").formula = "O6S3"
upos.metabolites.get_by_id("tton_p").formula = "O6S3"
upos.metabolites.get_by_id("tyr__D_c").formula = "C9H11NO3"
upos.metabolites.get_by_id("tyr__D_e").formula = "C9H11NO3"
upos.metabolites.get_by_id("tyr__D_p").formula = "C9H11NO3"
upos.metabolites.get_by_id("val__D_c").formula = "C5H11NO2"
upos.metabolites.get_by_id("val__D_e").formula = "C5H11NO2"
upos.metabolites.get_by_id("val__D_p").formula = "C5H11NO2"

# %%
#Fixing charges
#Evaluated manualy. Values obtained from BiGG, KEGG, ModelSEED, and CHEBI
upos.metabolites.get_by_id("12dag3p_BS_c").charge = -200
upos.metabolites.get_by_id("14dh2napcoa_c").charge = -4
upos.metabolites.get_by_id("1ag3p_BS_c").charge = -200
upos.metabolites.get_by_id("1hdec9eg3p_c").charge = -2
upos.metabolites.get_by_id("1hdec9eg3p_p").charge = -2
upos.metabolites.get_by_id("1p2cbxl_c").charge = -1
upos.metabolites.get_by_id("1py4h3c_c").charge = -1
upos.metabolites.get_by_id("23dappa_e").charge = 1
upos.metabolites.get_by_id("23dhacoa_c").charge = -5
upos.metabolites.get_by_id("23dhb_c").charge = 0
upos.metabolites.get_by_id("23dhbzs_c").charge = 0
upos.metabolites.get_by_id("23dhbzs2_c").charge = 0
upos.metabolites.get_by_id("23dhbzs3_c").charge = 0
upos.metabolites.get_by_id("23dhbzs3_e").charge = 0
upos.metabolites.get_by_id("23dhbzs3_p").charge = 0
upos.metabolites.get_by_id("24dhhed_c").charge = -2
upos.metabolites.get_by_id("26dapime_c").charge = -1
upos.metabolites.get_by_id("2a3o4pob_c").charge = -2
upos.metabolites.get_by_id("2agpg120_c").charge = -1
upos.metabolites.get_by_id("2agpg120_p").charge = -1
upos.metabolites.get_by_id("2agpg161_c").charge = -1
upos.metabolites.get_by_id("2agpg161_p").charge = -1
upos.metabolites.get_by_id("2agpg180_c").charge = -1
upos.metabolites.get_by_id("2agpg180_p").charge = -1
upos.metabolites.get_by_id("2ahbut_c").charge = -1
upos.metabolites.get_by_id("2ddara_c").charge = -1
upos.metabolites.get_by_id("2ddecg3p_c").charge = -1
upos.metabolites.get_by_id("2ddecg3p_p").charge = -1
upos.metabolites.get_by_id("2dhguln_c").charge = -1
upos.metabolites.get_by_id("2dhphaccoa_c").charge = -4
upos.metabolites.get_by_id("2h3mb_c").charge = -3
upos.metabolites.get_by_id("2h3mb_e").charge = -3
upos.metabolites.get_by_id("2hadnt_c").charge = -1
upos.metabolites.get_by_id("2hdec9eg3p_c").charge = -1
upos.metabolites.get_by_id("2hdec9eg3p_p").charge = -1
upos.metabolites.get_by_id("2hdecg3p_c").charge = -1
upos.metabolites.get_by_id("2hdecg3p_p").charge = -1
upos.metabolites.get_by_id("2hh24dd_c").charge = -2
upos.metabolites.get_by_id("2hmc_c").charge = -2
upos.metabolites.get_by_id("2dr1p_c").charge = -2
upos.metabolites.get_by_id("2hchd_c").charge = -1
upos.metabolites.get_by_id("2hetdp_c").charge = -1
upos.metabolites.get_by_id("2ip3os_c").charge = -2
upos.metabolites.get_by_id("2maacoa_c").charge = -4
upos.metabolites.get_by_id("2mb_p_c").charge = -2
upos.metabolites.get_by_id("2mba_c").charge = -1
upos.metabolites.get_by_id("2mba_e").charge = -1
upos.metabolites.get_by_id("2me4p_c").charge = -2
upos.metabolites.get_by_id("2mpa_c").charge = -1
upos.metabolites.get_by_id("2mpa_e").charge = -1
upos.metabolites.get_by_id("2o3h4pbut_c").charge = -3
upos.metabolites.get_by_id("2o3mpt_c").charge = -1
upos.metabolites.get_by_id("2odecg3p_c").charge = -1
upos.metabolites.get_by_id("2odecg3p_p").charge = -1
upos.metabolites.get_by_id("2odec11eg3p_c").charge = -1
upos.metabolites.get_by_id("2odec11eg3p_p").charge = -1
upos.metabolites.get_by_id("2ohed_c").charge = -2
upos.metabolites.get_by_id("2omcm_c").charge = -2
upos.metabolites.get_by_id("2oxpaccoa_c").charge = -4
upos.metabolites.get_by_id("2ptcoa_c").charge = -4
upos.metabolites.get_by_id("2sephchc_c").charge = -3
upos.metabolites.get_by_id("2shchc_c").charge = -2
upos.metabolites.get_by_id("2tdec7eg3p_c").charge = -1
upos.metabolites.get_by_id("2tdec7eg3p_p").charge = -1
upos.metabolites.get_by_id("23dappa_c").charge = 1
upos.metabolites.get_by_id("23dappa_e").charge = 1
upos.metabolites.get_by_id("23dappa_p").charge = 1
upos.metabolites.get_by_id("23ddhb_c").charge = -1
upos.metabolites.get_by_id("34dhsa_c").charge = 0
upos.metabolites.get_by_id("3a2oprop_c").charge = -1
upos.metabolites.get_by_id("3h4atb_c").charge = -1
upos.metabolites.get_by_id("3h4atb_e").charge = -1
upos.metabolites.get_by_id("3h4atb_p").charge = -1
upos.metabolites.get_by_id("3h4atbcoa_c").charge = -4
upos.metabolites.get_by_id("3h6athcoa_c").charge = -4
upos.metabolites.get_by_id("3hbcoa__R_c").charge = -4
upos.metabolites.get_by_id("3hcmrs7eACP_c").charge = -1
upos.metabolites.get_by_id("3hddccoa_c").charge = -4
upos.metabolites.get_by_id("3hdd5coa_c").charge = -4
upos.metabolites.get_by_id("3hdd6coa_c").charge = -4
upos.metabolites.get_by_id("3hdecACP_c").charge = -1
upos.metabolites.get_by_id("3hhd58coa_c").charge = -4
upos.metabolites.get_by_id("3hdd6coa_c").charge = -4
upos.metabolites.get_by_id("33hmeoxobut_c").charge = -1
upos.metabolites.get_by_id("3hasp__L_c").charge = -1
upos.metabolites.get_by_id("3hdec4coa_c").charge = -4
upos.metabolites.get_by_id("3hpdecacoa_c").charge = -4
upos.metabolites.get_by_id("3hhdccoa_c").charge = -4
upos.metabolites.get_by_id("3hhdd7coa_c").charge = -4
upos.metabolites.get_by_id("3hhd710coa_c").charge = -4
upos.metabolites.get_by_id("3hhd58coa_c").charge = -4
upos.metabolites.get_by_id("3hhdd4coa_c").charge = -4
upos.metabolites.get_by_id("3hhpcoa_c").charge = -4
upos.metabolites.get_by_id("3hlnlccoa_c").charge = -4
upos.metabolites.get_by_id("3hmrsACP_c").charge = -1
upos.metabolites.get_by_id("3hnonacoa_c").charge = -4
upos.metabolites.get_by_id("3hocoa_c").charge = -4
upos.metabolites.get_by_id("3hoctACP_c").charge = -1
upos.metabolites.get_by_id("3hodcoa_c").charge = -4
upos.metabolites.get_by_id("3hpbcoa_c").charge = -4
upos.metabolites.get_by_id("3hodecoa_c").charge = -4
upos.metabolites.get_by_id("3hphxacoa_c").charge = -4
upos.metabolites.get_by_id("3hphpcoa_c").charge = -4
upos.metabolites.get_by_id("3hpnonacoa_c").charge = -4
upos.metabolites.get_by_id("3hpoctacoa_c").charge = -4
upos.metabolites.get_by_id("3hpptcoa_c").charge = -4
upos.metabolites.get_by_id("3hptslacoa_c").charge = -4
upos.metabolites.get_by_id("3hptcoa_c").charge = -4
upos.metabolites.get_by_id("3hptslacoa_c").charge = -4
upos.metabolites.get_by_id("3hsa_c").charge = 0
upos.metabolites.get_by_id("3htdccoa_c").charge = -4
upos.metabolites.get_by_id("3hvacccoa_c").charge = -4
upos.metabolites.get_by_id("3h4atb_c").charge = -1
upos.metabolites.get_by_id("3mba_c").charge = -1
upos.metabolites.get_by_id("3mba_e").charge = -1
upos.metabolites.get_by_id("3mgcoa_c").charge = -5
upos.metabolites.get_by_id("3mob_c").charge = -1
upos.metabolites.get_by_id("3o6athcoa_c").charge = -4
upos.metabolites.get_by_id("3odd5coa_c").charge = -4
upos.metabolites.get_by_id("3odd6coa_c").charge = -4
upos.metabolites.get_by_id("3oddccoa_c").charge = -4
upos.metabolites.get_by_id("3odec4coa_c").charge = -4
upos.metabolites.get_by_id("3ohd710coa_c").charge = -4
upos.metabolites.get_by_id("3ohdccoa_c").charge = -4
upos.metabolites.get_by_id("3ohd58coa_c").charge = -4
upos.metabolites.get_by_id("3ohdd4coa_c").charge = -4
upos.metabolites.get_by_id("3ohdd7coa_c").charge = -4
upos.metabolites.get_by_id("3ohpcoa_c").charge = -4
upos.metabolites.get_by_id("3olnlccoa_c").charge = -4
upos.metabolites.get_by_id("3ononacoa_c").charge = -4
upos.metabolites.get_by_id("3oodecoa_c").charge = -4
upos.metabolites.get_by_id("3opcoa_c").charge = -4
upos.metabolites.get_by_id("3opdecacoa_c").charge = -4
upos.metabolites.get_by_id("3opptcoa_c").charge = -4
upos.metabolites.get_by_id("3optcoa_c").charge = -4
upos.metabolites.get_by_id("3optslacoa_c").charge = -4
upos.metabolites.get_by_id("3ovacccoa_c").charge = -4
upos.metabolites.get_by_id("3oxdhscoa_c").charge = -5
upos.metabolites.get_by_id("3hpcoa_c").charge = -4
upos.metabolites.get_by_id("3opbcoa_c").charge = -4
upos.metabolites.get_by_id("3ophpcoa_c").charge = -4
upos.metabolites.get_by_id("3ophxacoa_c").charge = -4
upos.metabolites.get_by_id("3opnonacoa_c").charge = -4
upos.metabolites.get_by_id("3opoctacoa_c").charge = -4
upos.metabolites.get_by_id("3otdccoa_c").charge = -4
upos.metabolites.get_by_id("3oxptcoa_c").charge = -4
upos.metabolites.get_by_id("3padsel_c").charge = -4
upos.metabolites.get_by_id("3ptcoa_c").charge = -4
upos.metabolites.get_by_id("3uib_c").charge = -1
upos.metabolites.get_by_id("49dsha_c").charge = 0
upos.metabolites.get_by_id("4a2mpmpmd_c").charge = -1
upos.metabolites.get_by_id("4abzglu_c").charge = -2
upos.metabolites.get_by_id("4abzglu_e").charge = -2
upos.metabolites.get_by_id("4abzglu_p").charge = -2
upos.metabolites.get_by_id("4atb2coa_c").charge = -4
upos.metabolites.get_by_id("4atbcoa_c").charge = -4
upos.metabolites.get_by_id("4cml_c").charge = -2
upos.metabolites.get_by_id("4h2kpi_c").charge = -2
upos.metabolites.get_by_id("4hadnt_c").charge = -1
upos.metabolites.get_by_id("4hptcoa_c").charge = -4
upos.metabolites.get_by_id("4hptn_c").charge = -1
upos.metabolites.get_by_id("4hptn_e").charge = -1
upos.metabolites.get_by_id("4hptn_p").charge = -1
upos.metabolites.get_by_id("4hoxoh_c").charge = -1
upos.metabolites.get_by_id("4hoxpac_c").charge = -1
upos.metabolites.get_by_id("4hoxpac_e").charge = -1
upos.metabolites.get_by_id("4hoxpac_p").charge = -1
upos.metabolites.get_by_id("4oxptn_c").charge = -1
upos.metabolites.get_by_id("4oxptn_e").charge = -1
upos.metabolites.get_by_id("4oxptn_p").charge = -1
upos.metabolites.get_by_id("4oxptcoa_c").charge = -4
upos.metabolites.get_by_id("4pen_c").charge = -3
upos.metabolites.get_by_id("4poptcoa_c").charge = -6
upos.metabolites.get_by_id("5aizc_c").charge = -3
upos.metabolites.get_by_id("5ca1rpi_c").charge = -3
upos.metabolites.get_by_id("5cohe_c").charge = -3
upos.metabolites.get_by_id("5cmhmsa_c").charge = -2
upos.metabolites.get_by_id("5cmhm_c").charge = -3
upos.metabolites.get_by_id("5hiu_c").charge = -1
upos.metabolites.get_by_id("5ohhip_c").charge = -4
upos.metabolites.get_by_id("5ohhipcoa_c").charge = -4
upos.metabolites.get_by_id("6ath2coa_c").charge = -4
upos.metabolites.get_by_id("6atha_e").charge = -1
upos.metabolites.get_by_id("6atha_p").charge = -1
upos.metabolites.get_by_id("6athcoa_c").charge = -4
upos.metabolites.get_by_id("6pgg_c").charge = -2
upos.metabolites.get_by_id("9ohadd_c").charge = 0
upos.metabolites.get_by_id("a2m2prpnte_c").charge = -1
upos.metabolites.get_by_id("aad_c").charge = -2
upos.metabolites.get_by_id("acadl_c").charge = 0
upos.metabolites.get_by_id("acgam1p_c").charge = -2
upos.metabolites.get_by_id("acgam1p_e").charge = -2
upos.metabolites.get_by_id("acgam1p_p").charge = -2
upos.metabolites.get_by_id("acgam6p_c").charge = -2
upos.metabolites.get_by_id("acmanap_c").charge = -2
upos.metabolites.get_by_id("acmum6p_c").charge = -3
upos.metabolites.get_by_id("acon_c").charge = -3
upos.metabolites.get_by_id("ACP_c").charge = -1
upos.metabolites.get_by_id("acysbmn_c").charge = -1
upos.metabolites.get_by_id("acysbmn_e").charge = -1
upos.metabolites.get_by_id("adcob1nda_c").charge = -4
upos.metabolites.get_by_id("adsel_c").charge = -2
upos.metabolites.get_by_id("1agpg161_p").charge = -1
upos.metabolites.get_by_id("ah6p__D_c").charge = -2
upos.metabolites.get_by_id("air_c").charge = -2
upos.metabolites.get_by_id("al26da_c").charge = -2
upos.metabolites.get_by_id("ala_L_glu__L_c").charge = -1
upos.metabolites.get_by_id("ala_L_glu__L_e").charge = -1
upos.metabolites.get_by_id("algac__M_e").charge = -5
upos.metabolites.get_by_id("algac__M_p").charge = -5
upos.metabolites.get_by_id("algac_MG_14_e").charge = -5
upos.metabolites.get_by_id("algac_MG_23_e").charge = -5
upos.metabolites.get_by_id("algac_MG_32_e").charge = -5
upos.metabolites.get_by_id("algac_MG_41_e").charge = -5
upos.metabolites.get_by_id("algac_MG_14_p").charge = -5
upos.metabolites.get_by_id("algac_MG_23_p").charge = -5
upos.metabolites.get_by_id("algac_MG_32_p").charge = -5
upos.metabolites.get_by_id("algac_MG_41_p").charge = -5
upos.metabolites.get_by_id("alpro_c").charge = 1
upos.metabolites.get_by_id("ametam_c").charge = 2
upos.metabolites.get_by_id("amob_c").charge = 0
upos.metabolites.get_by_id("anhgm3p_c").charge = -2
upos.metabolites.get_by_id("anhgm3p_p").charge = -2
upos.metabolites.get_by_id("apoACP_c").charge = 0
upos.metabolites.get_by_id("appl_c").charge = 1
upos.metabolites.get_by_id("arachACP_c").charge = -1
upos.metabolites.get_by_id("argsuc_c").charge = -1
upos.metabolites.get_by_id("balamd_c").charge = 1
upos.metabolites.get_by_id("balamd_e").charge = 1
upos.metabolites.get_by_id("balamd_p").charge = 1
upos.metabolites.get_by_id("benzcoa_c").charge = -4
upos.metabolites.get_by_id("dtbt_c").charge = -1
upos.metabolites.get_by_id("but2encoa_c").charge = -4
upos.metabolites.get_by_id("butcoa_c").charge = -2
upos.metabolites.get_by_id("buts_c").charge = -1
upos.metabolites.get_by_id("buts_e").charge = -1
upos.metabolites.get_by_id("bz12diol_c").charge = -1
upos.metabolites.get_by_id("bzsucc_c").charge = -2
upos.metabolites.get_by_id("bzsuccoa_c").charge = -5
upos.metabolites.get_by_id("campp_c").charge = -2
upos.metabolites.get_by_id("cchoxod_c").charge = -1
upos.metabolites.get_by_id("ccmuac_c").charge = -2
upos.metabolites.get_by_id("cdigmp_c").charge = -2
upos.metabolites.get_by_id("cdpoctdecglc_c").charge = -1
upos.metabolites.get_by_id("cdpdtetdecglc_c").charge = -1
upos.metabolites.get_by_id("cdpdhexdecglc_c").charge =-2
upos.metabolites.get_by_id("chol4en3one_c").charge = 0
upos.metabolites.get_by_id("cinmcoa_c").charge = -4
upos.metabolites.get_by_id("cmcbtt_c").charge = 1
upos.metabolites.get_by_id("cmcbtt_e").charge = 1
upos.metabolites.get_by_id("cmcbtt_p").charge = 1
upos.metabolites.get_by_id("cob1nda_c").charge = -5
upos.metabolites.get_by_id("cpgn_c").charge = -1
upos.metabolites.get_by_id("cpgn_e").charge = -1
upos.metabolites.get_by_id("cpgn_p").charge = -1
upos.metabolites.get_by_id("cpgn_un_c").charge = -4
upos.metabolites.get_by_id("cpgn_un_e").charge = -4
upos.metabolites.get_by_id("cpgn_un_p").charge = -4
upos.metabolites.get_by_id("cpp3_c").charge = -5
upos.metabolites.get_by_id("ctbt_c").charge = 0
upos.metabolites.get_by_id("ctbt_e").charge = 0
upos.metabolites.get_by_id("ctbt_p").charge = 0
upos.metabolites.get_by_id("ctbtcoa_c").charge = -3
upos.metabolites.get_by_id("crncoa_c").charge = -3
upos.metabolites.get_by_id("cspmd_c").charge = 2
upos.metabolites.get_by_id("d23hb_e").charge = 1
upos.metabolites.get_by_id("d5kgp_c").charge = -3
upos.metabolites.get_by_id("dag_MRSA_c").charge = 2
upos.metabolites.get_by_id("db4p_c").charge = -2
upos.metabolites.get_by_id("dcaACP_c").charge = -1
upos.metabolites.get_by_id("dcamp_c").charge = -4
upos.metabolites.get_by_id("dccoa_c").charge = -4
upos.metabolites.get_by_id("dd_3_6_coa_c").charge = -4
upos.metabolites.get_by_id("dd6_2_coa_c").charge = -4
upos.metabolites.get_by_id("ddcap_c").charge = -1
upos.metabolites.get_by_id("ddcaACP_c").charge = -1
upos.metabolites.get_by_id("ddcoa_c").charge = -4
upos.metabolites.get_by_id("ddecoa_c").charge = -4
upos.metabolites.get_by_id("dde2coa_c").charge = -4
upos.metabolites.get_by_id("dded3coa_c").charge = -4
upos.metabolites.get_by_id("dec4coa_c").charge = -4
upos.metabolites.get_by_id("dec4_2_coa_c").charge = -4
upos.metabolites.get_by_id("decoa_c").charge = -4
upos.metabolites.get_by_id("dgal6p_c").charge = -2
upos.metabolites.get_by_id("dgudbutn_c").charge = 2
upos.metabolites.get_by_id("dgudbutn_e").charge = 2
upos.metabolites.get_by_id("dgudbutn_p").charge = 2
upos.metabolites.get_by_id("dh3mchc_c").charge = -1
upos.metabolites.get_by_id("dhcrncoa_c").charge = -3
upos.metabolites.get_by_id("dhgly_c").charge = -1
upos.metabolites.get_by_id("dhpmp_c").charge = -2
upos.metabolites.get_by_id("dhptdd_c").charge = -2
upos.metabolites.get_by_id("dhptdp_c").charge = -2
upos.metabolites.get_by_id("dmlgnc_c").charge = -1
upos.metabolites.get_by_id("dmlz_c").charge = 0
upos.metabolites.get_by_id("dmanur_e").charge = -2
upos.metabolites.get_by_id("dmanur_p").charge = -2
upos.metabolites.get_by_id("doscoa_c").charge = -16
upos.metabolites.get_by_id("dr5p_c").charge = -2
upos.metabolites.get_by_id("dtbt_e").charge = -1
upos.metabolites.get_by_id("dscl_c").charge = -7
upos.metabolites.get_by_id("dxylnt_c").charge = -1
upos.metabolites.get_by_id("dxylnt_e").charge = -1
upos.metabolites.get_by_id("dxylnt_p").charge = -1
upos.metabolites.get_by_id("eiscoa_c").charge = -13
upos.metabolites.get_by_id("enter_c").charge = 0
upos.metabolites.get_by_id("enter_e").charge = 0
upos.metabolites.get_by_id("enter_p").charge = 0
upos.metabolites.get_by_id("fa1_c").charge = -1
upos.metabolites.get_by_id("fa1coa_c").charge = -4
upos.metabolites.get_by_id("fa3_c").charge = -1
upos.metabolites.get_by_id("fa3coa_c").charge = -4
upos.metabolites.get_by_id("fa4_c").charge = -1
upos.metabolites.get_by_id("fa4coa_c").charge = -4
upos.metabolites.get_by_id("fa6_c").charge = -1
upos.metabolites.get_by_id("fa6coa_c").charge = -4
upos.metabolites.get_by_id("fa11_c").charge = -1
upos.metabolites.get_by_id("fa11coa_c").charge = -4
upos.metabolites.get_by_id("fa12_c").charge = -1
upos.metabolites.get_by_id("fa12coa_c").charge = -4
upos.metabolites.get_by_id("fad_c").charge = -2
upos.metabolites.get_by_id("fad_e").charge = -2
upos.metabolites.get_by_id("fad_p").charge = -2
upos.metabolites.get_by_id("fadh2_c").charge = -2 
upos.metabolites.get_by_id("fbac_kt_c").charge = -1
upos.metabolites.get_by_id("fbac_kt_p").charge = -1
upos.metabolites.get_by_id("fc1p_c").charge = -2
upos.metabolites.get_by_id("fcmcbtt_c").charge = 4
upos.metabolites.get_by_id("fcmcbtt_e").charge = 4
upos.metabolites.get_by_id("fcmcbtt_p").charge = 4
upos.metabolites.get_by_id("fdp_c").charge = -4
upos.metabolites.get_by_id("fdxo_2_2_c").charge = 2
upos.metabolites.get_by_id("fdxox_c").charge = 1
upos.metabolites.get_by_id("fdxrd_c").charge = 0
upos.metabolites.get_by_id("fe3dcit_c").charge = -3
upos.metabolites.get_by_id("fe3dcit_e").charge = -3
upos.metabolites.get_by_id("fe3dcit_p").charge = -3
upos.metabolites.get_by_id("fe3dhbzs_c").charge = 3
upos.metabolites.get_by_id("fe3dhbzs_e").charge = 3
upos.metabolites.get_by_id("fe3dhbzs_p").charge = 3
upos.metabolites.get_by_id("fe3dhbzs3_c").charge = 3
upos.metabolites.get_by_id("fe3dhbzs3_e").charge = 3
upos.metabolites.get_by_id("fe3dhbzs3_p").charge = 3
upos.metabolites.get_by_id("fe3mcbtt_c").charge = 5
upos.metabolites.get_by_id("fe3mcbtt_e").charge = 5
upos.metabolites.get_by_id("fe3mcbtt_p").charge = 5
upos.metabolites.get_by_id("fe3pyovd_kt_e").charge = 2
upos.metabolites.get_by_id("fe3pyovd_kt_p").charge = 2
upos.metabolites.get_by_id("fecpp3_c").charge = -5
upos.metabolites.get_by_id("feenter_c").charge = 3
upos.metabolites.get_by_id("feenter_e").charge = 3
upos.metabolites.get_by_id("feenter_p").charge = 3
upos.metabolites.get_by_id("feoxam_c").charge = 1
upos.metabolites.get_by_id("feoxam_e").charge = 1
upos.metabolites.get_by_id("feoxam_p").charge = 1
upos.metabolites.get_by_id("feoxam_un_c").charge = -2
upos.metabolites.get_by_id("feoxam_un_e").charge = -2
upos.metabolites.get_by_id("feoxam_un_p").charge = -2
upos.metabolites.get_by_id("fgam_c").charge = -2
upos.metabolites.get_by_id("ficytC_c").charge = 3
upos.metabolites.get_by_id("ficytb_c").charge = 2
upos.metabolites.get_by_id("ficytc_c").charge = 1
upos.metabolites.get_by_id("fmcbtt_c").charge = 4
upos.metabolites.get_by_id("fmn_c").charge = -2
upos.metabolites.get_by_id("fmn_e").charge = -2
upos.metabolites.get_by_id("fmn_p").charge = -2
upos.metabolites.get_by_id("fmnh2_c").charge = -2
upos.metabolites.get_by_id("fmnRD_c").charge = -2
upos.metabolites.get_by_id("focytc_c").charge = 1
upos.metabolites.get_by_id("focytC_c").charge = 2
upos.metabolites.get_by_id("forglu_c").charge = -1
upos.metabolites.get_by_id("forglu_e").charge = -1
upos.metabolites.get_by_id("fpram_c").charge = -2
upos.metabolites.get_by_id("frmd_c").charge = 0
upos.metabolites.get_by_id("fruur_c").charge = -1
upos.metabolites.get_by_id("fruur_e").charge = -1
upos.metabolites.get_by_id("fruur_p").charge = -1
upos.metabolites.get_by_id("frulysp_c").charge =-1
upos.metabolites.get_by_id("g3p_c").charge = -2
upos.metabolites.get_by_id("g3pg_c").charge = -1
upos.metabolites.get_by_id("g3pg_e").charge = -1
upos.metabolites.get_by_id("g3pg_p").charge = -1
upos.metabolites.get_by_id("g6p_A_c").charge = -2
upos.metabolites.get_by_id("gdptp_c").charge = -7
upos.metabolites.get_by_id("gdpmanur_c").charge = -3
upos.metabolites.get_by_id("gg13dampp_c").charge = 1
upos.metabolites.get_by_id("gg15dap_c").charge = 1
upos.metabolites.get_by_id("ggala_B_c").charge = -1
upos.metabolites.get_by_id("ggaptn_c").charge = -1
upos.metabolites.get_by_id("ggspmd_c").charge = 2
upos.metabolites.get_by_id("glcur1p_e").charge = -3
upos.metabolites.get_by_id("glcur1p_p").charge = -3
upos.metabolites.get_by_id("gly_asp__L_c").charge = -1
upos.metabolites.get_by_id("gly_asp__L_e").charge = -1
upos.metabolites.get_by_id("gly_glu__L_c").charge = -1
upos.metabolites.get_by_id("gly_glu__L_e").charge = -1
upos.metabolites.get_by_id("gly_pro__L_c").charge = 1
upos.metabolites.get_by_id("gly_pro__L_e").charge = 1
upos.metabolites.get_by_id("glybcoa_c").charge = -3
upos.metabolites.get_by_id("glyglu_c").charge = -1
upos.metabolites.get_by_id("glyglu_e").charge = -1
upos.metabolites.get_by_id("glyglu_p").charge = -1
upos.metabolites.get_by_id("gtca1_45_BS_c").charge = -45
upos.metabolites.get_by_id("gtca2_45_BS_c").charge = -45
upos.metabolites.get_by_id("gtca3_45_BS_c").charge = -45
upos.metabolites.get_by_id("gcvHalip_c").charge = -4
upos.metabolites.get_by_id("gcvHdhlip_c").charge = -5
upos.metabolites.get_by_id("gcvhlipl_c").charge = -5
upos.metabolites.get_by_id("gcvHL_ADPr_c").charge = -4
upos.metabolites.get_by_id("gcvHL_nhLA_c").charge = -3
upos.metabolites.get_by_id("gluala_c").charge = -1
upos.metabolites.get_by_id("hchol_c").charge = 0
upos.metabolites.get_by_id("hd2coa_c").charge = -4
upos.metabolites.get_by_id("hd_7_10_coa_c").charge = -4
upos.metabolites.get_by_id("hd710_2_coa_c").charge = -4
upos.metabolites.get_by_id("hdcap_c").charge = -1
upos.metabolites.get_by_id("hdceap_c").charge = -1
upos.metabolites.get_by_id("hdd4_2_coa_c").charge = -4
upos.metabolites.get_by_id("hdd4coa_c").charge = -4
upos.metabolites.get_by_id("hdd7coa_c").charge = -4
upos.metabolites.get_by_id("hdd7_2_coa_c").charge = -4
upos.metabolites.get_by_id("hemeO_c").charge = -2
upos.metabolites.get_by_id("hethmpp_c").charge = -2
upos.metabolites.get_by_id("hepdp_c").charge = -3
upos.metabolites.get_by_id("hexcoa_c").charge = -1
upos.metabolites.get_by_id("hexdcoa_c").charge = -7
upos.metabolites.get_by_id("hexscoa_c").charge = -22
upos.metabolites.get_by_id("hip_c").charge = -4
upos.metabolites.get_by_id("hipcoa_c").charge = -4
upos.metabolites.get_by_id("hipecoa_c").charge = -4
upos.metabolites.get_by_id("hipocoa_c").charge = -4
upos.metabolites.get_by_id("hipohcoa_c").charge = -4
upos.metabolites.get_by_id("histda_c").charge = 1
upos.metabolites.get_by_id("hkmpp_c").charge = -2
upos.metabolites.get_by_id("hkntd_c").charge = -2
upos.metabolites.get_by_id("hmbpp_c").charge = -4
upos.metabolites.get_by_id("hmccm_c").charge = -2
upos.metabolites.get_by_id("hmccms_c").charge = -1
upos.metabolites.get_by_id("hmpscoa_c").charge = -5
upos.metabolites.get_by_id("hp2coa_c").charge = -4
upos.metabolites.get_by_id("hpta_c").charge = -1
upos.metabolites.get_by_id("hpta_e").charge = -1
upos.metabolites.get_by_id("hpta_p").charge = -1
upos.metabolites.get_by_id("hptcoa_c").charge = -4
upos.metabolites.get_by_id("htdol__L_c").charge = 1
upos.metabolites.get_by_id("ib_p_c").charge = -2
upos.metabolites.get_by_id("isobutp_c").charge = -2
upos.metabolites.get_by_id("istfrnA_e").charge = 2
upos.metabolites.get_by_id("istfrnB_e").charge = -3
upos.metabolites.get_by_id("iv_p_c").charge = -2
upos.metabolites.get_by_id("ival_c").charge = -1
upos.metabolites.get_by_id("ival_e").charge = -1
upos.metabolites.get_by_id("lac6p_c").charge = -2
upos.metabolites.get_by_id("ldpcde_c").charge = -3
upos.metabolites.get_by_id("lipoamp_c").charge = -1
upos.metabolites.get_by_id("lipoate_c").charge = 0
upos.metabolites.get_by_id("lipoate_e").charge = 0
upos.metabolites.get_by_id("lipoate_p").charge = 0
upos.metabolites.get_by_id("lipo1_24_BS_c").charge = -2400
upos.metabolites.get_by_id("lipo2_24_BS_c").charge = -2400
upos.metabolites.get_by_id("lipo3_24_BS_c").charge = -2400
upos.metabolites.get_by_id("lipo4_24_BS_c").charge = -2400
upos.metabolites.get_by_id("lipopb_c").charge = 1
upos.metabolites.get_by_id("lgt_s_c").charge = -1
upos.metabolites.get_by_id("lnlccoa_c").charge = -4
upos.metabolites.get_by_id("lnlc2coa_c").charge = -4
upos.metabolites.get_by_id("m2butp_c").charge = -1
upos.metabolites.get_by_id("malt1p_c").charge = -2
upos.metabolites.get_by_id("man1p_c").charge = -2
upos.metabolites.get_by_id("man1p_e").charge = -2
upos.metabolites.get_by_id("man6p_c").charge = -2
upos.metabolites.get_by_id("man6p_e").charge = -2
upos.metabolites.get_by_id("man6p_p").charge = -2
upos.metabolites.get_by_id("man6pglyc_c").charge = -3
upos.metabolites.get_by_id("man6pglyc_e").charge = -3
upos.metabolites.get_by_id("manur_e").charge = -1
upos.metabolites.get_by_id("manur_p").charge = -1
upos.metabolites.get_by_id("mbhn_c").charge = -1
upos.metabolites.get_by_id("mcbtt_c").charge = 2
upos.metabolites.get_by_id("metglcur_c").charge = -1
upos.metabolites.get_by_id("metglcur_e").charge = -1
upos.metabolites.get_by_id("metglcur_p").charge = -1
upos.metabolites.get_by_id("met_L_ala__L_c").charge = -1
upos.metabolites.get_by_id("met_L_ala__L_e").charge = -1
upos.metabolites.get_by_id("mhpglu_c").charge = -4
upos.metabolites.get_by_id("mi3p__D_c").charge = -2
upos.metabolites.get_by_id("mcbtt_c").charge = 2
upos.metabolites.get_by_id("mcbtt_e").charge = 2
upos.metabolites.get_by_id("mcbtt_p").charge = 2
upos.metabolites.get_by_id("mmalsa__S_c").charge = -1
upos.metabolites.get_by_id("mmet_c").charge = 1
upos.metabolites.get_by_id("mmet_e").charge = 1
upos.metabolites.get_by_id("mmet_p").charge = 1
upos.metabolites.get_by_id("mqn7_c").charge = 0
upos.metabolites.get_by_id("mql7_c").charge = 0
upos.metabolites.get_by_id("m_tol_c").charge = -1
upos.metabolites.get_by_id("mucl_c").charge = -1
upos.metabolites.get_by_id("murein3px3p_p").charge = -4
upos.metabolites.get_by_id("murein4px4p_p").charge = -4
upos.metabolites.get_by_id("murein5px4p_p").charge = -4
upos.metabolites.get_by_id("murein5px4px4p_p").charge = -6
upos.metabolites.get_by_id("myrsACP_c").charge = -1
upos.metabolites.get_by_id("nacg_c").charge = -1
upos.metabolites.get_by_id("nadhx__S_c").charge = -2
upos.metabolites.get_by_id("nadhx__R_c").charge = -2
upos.metabolites.get_by_id("nadphx__S_c").charge = -4
upos.metabolites.get_by_id("nadphx__R_c").charge = -4
upos.metabolites.get_by_id("Ncarbsar_c").charge = -1
upos.metabolites.get_by_id("nflgln_c").charge = -1
upos.metabolites.get_by_id("Nforglu_c").charge = -2
upos.metabolites.get_by_id("nflgln_c").charge = -1
upos.metabolites.get_by_id("nona2coa_c").charge = -4
upos.metabolites.get_by_id("nonacoa_c").charge = -4
upos.metabolites.get_by_id("oca_c").charge = -3
upos.metabolites.get_by_id("oc2coa_c").charge = -4 #Kept the number
upos.metabolites.get_by_id("ocdcaACP_c").charge = -1
upos.metabolites.get_by_id("ocdcap_c").charge = -1
upos.metabolites.get_by_id("ocdceap_c").charge = -1
upos.metabolites.get_by_id("octdcoa_c").charge = -10
upos.metabolites.get_by_id("octeACP_c").charge = -1
upos.metabolites.get_by_id("octscoa_c").charge = -25
upos.metabolites.get_by_id("octscoa_e").charge = -25
upos.metabolites.get_by_id("ode2coa_c").charge = -4
upos.metabolites.get_by_id("omaenol_c").charge = -3
upos.metabolites.get_by_id("omaketo_c").charge = -3
upos.metabolites.get_by_id("op4en_c").charge = -1
upos.metabolites.get_by_id("osuc_c").charge = -3
upos.metabolites.get_by_id("oxalc_c").charge = -2
upos.metabolites.get_by_id("pa120_c").charge = -2
upos.metabolites.get_by_id("pa140_c").charge = -2
upos.metabolites.get_by_id("pa141_c").charge = -2
upos.metabolites.get_by_id("pa161_c").charge = -2
upos.metabolites.get_by_id("pa180_c").charge = -2
upos.metabolites.get_by_id("pa181_c").charge = -2
upos.metabolites.get_by_id("pa120_p").charge = -2
upos.metabolites.get_by_id("pa140_p").charge = -2
upos.metabolites.get_by_id("pa141_p").charge = -2
upos.metabolites.get_by_id("pa161_p").charge = -2
upos.metabolites.get_by_id("pa180_p").charge = -2
upos.metabolites.get_by_id("pa181_p").charge = -2
upos.metabolites.get_by_id("pa_LLA_c").charge = -200
upos.metabolites.get_by_id("Pald_c").charge = -2
upos.metabolites.get_by_id("pald_c").charge = -2
upos.metabolites.get_by_id("palmACP_c").charge = -1
upos.metabolites.get_by_id("pbcoa_c").charge = -4
upos.metabolites.get_by_id("pb2coa_c").charge = -4
upos.metabolites.get_by_id("pdca2coa_c").charge = -4
upos.metabolites.get_by_id("pdcacoa_c").charge = -4
upos.metabolites.get_by_id("pendp_c").charge = -3
upos.metabolites.get_by_id("peptido_BS_c").charge = -2
upos.metabolites.get_by_id("pg120_c").charge = -1
upos.metabolites.get_by_id("pg140_c").charge = -1
upos.metabolites.get_by_id("pg141_c").charge = -1
upos.metabolites.get_by_id("pg160_c").charge = -1
upos.metabolites.get_by_id("pg161_c").charge = -1
upos.metabolites.get_by_id("pg180_c").charge = -1
upos.metabolites.get_by_id("pg181_c").charge = -1
upos.metabolites.get_by_id("pg120_p").charge = -1
upos.metabolites.get_by_id("pg140_p").charge = -1
upos.metabolites.get_by_id("pg141_p").charge = -1
upos.metabolites.get_by_id("pg160_p").charge = -1
upos.metabolites.get_by_id("pg161_p").charge = -1
upos.metabolites.get_by_id("pg180_p").charge = -1
upos.metabolites.get_by_id("pg181_p").charge = -1
upos.metabolites.get_by_id("pgp120_c").charge = -3
upos.metabolites.get_by_id("pgp140_c").charge = -3
upos.metabolites.get_by_id("pgp141_c").charge = -3
upos.metabolites.get_by_id("pgp160_c").charge = -3
upos.metabolites.get_by_id("pgp161_c").charge = -3
upos.metabolites.get_by_id("pgp180_c").charge = -3
upos.metabolites.get_by_id("pgp181_c").charge = -3
upos.metabolites.get_by_id("pgp120_p").charge = -3
upos.metabolites.get_by_id("pgp140_p").charge = -3
upos.metabolites.get_by_id("pgp141_p").charge = -3
upos.metabolites.get_by_id("pgp160_p").charge = -3
upos.metabolites.get_by_id("pgp161_p").charge = -3
upos.metabolites.get_by_id("pgp180_p").charge = -3
upos.metabolites.get_by_id("pgp181_p").charge = -3
upos.metabolites.get_by_id("phdcaACP_c").charge = -1
upos.metabolites.get_by_id("phdcacoa_c").charge = -3
upos.metabolites.get_by_id("phedca_e").charge = -1
upos.metabolites.get_by_id("phedca_p").charge = -1
upos.metabolites.get_by_id("phehpa_e").charge = -1
upos.metabolites.get_by_id("phehpa_p").charge = -1
upos.metabolites.get_by_id("phehxa_e").charge = -1
upos.metabolites.get_by_id("phehxa_p").charge = -1
upos.metabolites.get_by_id("phenona_e").charge = -1
upos.metabolites.get_by_id("phenona_p").charge = -1
upos.metabolites.get_by_id("pheocta_e").charge = -1
upos.metabolites.get_by_id("pheocta_p").charge = -1
upos.metabolites.get_by_id("phept_e").charge = -1
upos.metabolites.get_by_id("phept_p").charge = -1
upos.metabolites.get_by_id("phitcoa_c").charge = -5
upos.metabolites.get_by_id("phnac_c").charge = -3
upos.metabolites.get_by_id("phpcoa_c").charge = -4
upos.metabolites.get_by_id("php2coa_c").charge = -4
upos.metabolites.get_by_id("phppcoa_c").charge = -4
upos.metabolites.get_by_id("phxacoa_c").charge = -4
upos.metabolites.get_by_id("phxa2coa_c").charge = -4
upos.metabolites.get_by_id("pnonacoa_c").charge = -4
upos.metabolites.get_by_id("pnona2coa_c").charge = -4
upos.metabolites.get_by_id("pocta2coa_c").charge = -4
upos.metabolites.get_by_id("poctacoa_c").charge = -4
upos.metabolites.get_by_id("ppad_c").charge = -2
upos.metabolites.get_by_id("ppgpp_c").charge = -6
upos.metabolites.get_by_id("pphn_c").charge = -2
upos.metabolites.get_by_id("pphos_c").charge = -2
upos.metabolites.get_by_id("ppi50_c").charge = -51
upos.metabolites.get_by_id("pptcoa_c").charge = -4
upos.metabolites.get_by_id("ppt2coa_c").charge = -4
upos.metabolites.get_by_id("pppi_c").charge = -4
upos.metabolites.get_by_id("pqq_c").charge = -3
upos.metabolites.get_by_id("pqq_p").charge = -3
upos.metabolites.get_by_id("pqqh2_c").charge = -3
upos.metabolites.get_by_id("pqqh2_p").charge = -3
upos.metabolites.get_by_id("prbatp_c").charge = -6
upos.metabolites.get_by_id("prbamp_c").charge = -4
upos.metabolites.get_by_id("prealgac_M1_p").charge = -5
upos.metabolites.get_by_id("prealgac_M2_p").charge = -5
upos.metabolites.get_by_id("prealgac_M3_p").charge = -5
upos.metabolites.get_by_id("prealgac_M4_p").charge = -5
upos.metabolites.get_by_id("prealginate_G_e").charge = -5
upos.metabolites.get_by_id("prealginate_G_p").charge = -5
upos.metabolites.get_by_id("prealg_MG_14_e").charge = -5
upos.metabolites.get_by_id("prealg_MG_23_e").charge = -5
upos.metabolites.get_by_id("prealg_MG_32_e").charge = -5
upos.metabolites.get_by_id("prealg_MG_41_e").charge = -5
upos.metabolites.get_by_id("prealg_MG_14_p").charge = -5
upos.metabolites.get_by_id("prealg_MG_23_p").charge = -5
upos.metabolites.get_by_id("prealg_MG_32_p").charge = -5
upos.metabolites.get_by_id("prealg_MG_41_p").charge = -5
upos.metabolites.get_by_id("prealginate__M_p").charge = -5
upos.metabolites.get_by_id("prephth_c").charge = -1
upos.metabolites.get_by_id("prepphth_c").charge = -1
upos.metabolites.get_by_id("prephthcoa_c").charge = -4
upos.metabolites.get_by_id("prephthACP_c").charge = -1
upos.metabolites.get_by_id("prepphthACP_c").charge = -1
upos.metabolites.get_by_id("prohisglu_c").charge = -1
upos.metabolites.get_by_id("prohisglu_e").charge = -1
upos.metabolites.get_by_id("ps120_c").charge = -1
upos.metabolites.get_by_id("ps141_c").charge = -1
upos.metabolites.get_by_id("ps160_c").charge = -1
upos.metabolites.get_by_id("ps161_c").charge = -1
upos.metabolites.get_by_id("ps180_c").charge = -1
upos.metabolites.get_by_id("ps181_c").charge = -1
upos.metabolites.get_by_id("pta_c").charge = -1
upos.metabolites.get_by_id("pt2coa_c").charge = -4
upos.metabolites.get_by_id("ptcoa_c").charge = -4
upos.metabolites.get_by_id("ptd1ino160_c").charge = -1
upos.metabolites.get_by_id("ptsla_e").charge = -1
upos.metabolites.get_by_id("ptsla_p").charge = -1
upos.metabolites.get_by_id("ptsla2coa_c").charge = -4
upos.metabolites.get_by_id("ptslacoa_c").charge = -4
upos.metabolites.get_by_id("pvdiq_p").charge = -1
upos.metabolites.get_by_id("pyovd_kt_e").charge = -1
upos.metabolites.get_by_id("pyovd_kt_p").charge = -1
upos.metabolites.get_by_id("r5p_c").charge = -2
upos.metabolites.get_by_id("r5p_e").charge = -2
upos.metabolites.get_by_id("r5p_p").charge = -2
upos.metabolites.get_by_id("R3hdec4e_c").charge = -1
upos.metabolites.get_by_id("R3hdec4e_e").charge = -1
upos.metabolites.get_by_id("R3hdec4e_p").charge = -1
upos.metabolites.get_by_id("R3hdec4coa_c").charge = -4
upos.metabolites.get_by_id("R_3h4atba_c").charge = -1
upos.metabolites.get_by_id("R_3h4atba_e").charge = -1
upos.metabolites.get_by_id("R_3h4atba_p").charge = -1
upos.metabolites.get_by_id("R_3h4atbcoa_c").charge = -4
upos.metabolites.get_by_id("R_3h6atha_c").charge = -1
upos.metabolites.get_by_id("R_3h6atha_e").charge = -1
upos.metabolites.get_by_id("R_3h6atha_p").charge = -1
upos.metabolites.get_by_id("R_3h6athcoa_c").charge = -4
upos.metabolites.get_by_id("R_3hcddec5ecoa_c").charge = -4
upos.metabolites.get_by_id("R_3hcmrs7e_c").charge = -1
upos.metabolites.get_by_id("R_3hcmrs7e_e").charge = -1
upos.metabolites.get_by_id("R_3hcmrs7e_p").charge = -1
upos.metabolites.get_by_id("R_3hcmrs7ecoa_c").charge = -4
upos.metabolites.get_by_id("R_3hdcaa_c").charge = -1
upos.metabolites.get_by_id("R_3hdcaa_e").charge = -1
upos.metabolites.get_by_id("R_3hdcaa_p").charge = -1
upos.metabolites.get_by_id("R_3hdcoa_c").charge = -4
upos.metabolites.get_by_id("R_3hdd5ea_c").charge = -1
upos.metabolites.get_by_id("R_3hdd5ea_e").charge = -1
upos.metabolites.get_by_id("R_3hdd5ea_p").charge = -1
upos.metabolites.get_by_id("R_3hhcoa_c").charge = -4
upos.metabolites.get_by_id("R_3hdd6e_c").charge = -1
upos.metabolites.get_by_id("R_3hdd6e_e").charge = -1
upos.metabolites.get_by_id("R_3hdd6e_p").charge = -1
upos.metabolites.get_by_id("R_3hdd6coa_c").charge = -4
upos.metabolites.get_by_id("R_3hhdca_c").charge = -1
upos.metabolites.get_by_id("R_3hhdca_e").charge = -1
upos.metabolites.get_by_id("R_3hhdca_p").charge = -1
upos.metabolites.get_by_id("R_3hhdcoa_c").charge = -4
upos.metabolites.get_by_id("R_3hhpa_c").charge = -1
upos.metabolites.get_by_id("R_3hhpa_e").charge = -1
upos.metabolites.get_by_id("R_3hhpa_p").charge = -1
upos.metabolites.get_by_id("R_3hhpcoa_c").charge = -4
upos.metabolites.get_by_id("R_3hhxa_c").charge = -1
upos.metabolites.get_by_id("R_3hhxa_e").charge = -1
upos.metabolites.get_by_id("R_3hhxa_p").charge = -1
upos.metabolites.get_by_id("R_3hpdeca_c").charge = -1
upos.metabolites.get_by_id("R_3hpdeca_e").charge = -1
upos.metabolites.get_by_id("R_3hpdeca_p").charge = -1
upos.metabolites.get_by_id("R_3hpdecacoa_c").charge = -4
upos.metabolites.get_by_id("R_3htd5e_c").charge = -1
upos.metabolites.get_by_id("R_3htd5e_e").charge = -1
upos.metabolites.get_by_id("R_3htd5e_p").charge = -1
upos.metabolites.get_by_id("R_3htd5coa_c").charge = -4
upos.metabolites.get_by_id("R_3hdda_c").charge = -1
upos.metabolites.get_by_id("R_3hdda_e").charge = -1
upos.metabolites.get_by_id("R_3hdda_p").charge = -1
upos.metabolites.get_by_id("R_3hddcoa_c").charge = -4
upos.metabolites.get_by_id("R_3hmrscoa_c").charge = -4
upos.metabolites.get_by_id("R_3hnonaa_c").charge = -1
upos.metabolites.get_by_id("R_3hnonaa_e").charge = -1
upos.metabolites.get_by_id("R_3hnonaa_p").charge = -1
upos.metabolites.get_by_id("R_3hnonacoa_c").charge = -4
upos.metabolites.get_by_id("R_3hocoa_c").charge = -4
upos.metabolites.get_by_id("R_3hocta_c").charge = -1
upos.metabolites.get_by_id("R_3hocta_e").charge = -1
upos.metabolites.get_by_id("R_3hocta_p").charge = -1
upos.metabolites.get_by_id("R_3hpba_c").charge = -1
upos.metabolites.get_by_id("R_3hpba_e").charge = -1
upos.metabolites.get_by_id("R_3hpba_p").charge = -1
upos.metabolites.get_by_id("R_3hpbcoa_c").charge = -4
upos.metabolites.get_by_id("R_3hphpa_c").charge = -1
upos.metabolites.get_by_id("R_3hphpa_e").charge = -1
upos.metabolites.get_by_id("R_3hphpa_p").charge = -1
upos.metabolites.get_by_id("R_3hphpcoa_c").charge = -4
upos.metabolites.get_by_id("R_3hphxa_c").charge = -1
upos.metabolites.get_by_id("R_3hphxa_e").charge = -1
upos.metabolites.get_by_id("R_3hphxa_p").charge = -1
upos.metabolites.get_by_id("R_3hphxacoa_c").charge = -4
upos.metabolites.get_by_id("R_3hpnona_c").charge = -1
upos.metabolites.get_by_id("R_3hpnona_e").charge = -1
upos.metabolites.get_by_id("R_3hpnona_p").charge = -1
upos.metabolites.get_by_id("R_3hpnonacoa_c").charge = -4
upos.metabolites.get_by_id("R_3hpocta_c").charge = -1
upos.metabolites.get_by_id("R_3hpocta_e").charge = -1
upos.metabolites.get_by_id("R_3hpocta_p").charge = -1
upos.metabolites.get_by_id("R_3hpoctacoa_c").charge = -4
upos.metabolites.get_by_id("R_3hppta_c").charge = -1
upos.metabolites.get_by_id("R_3hppta_e").charge = -1
upos.metabolites.get_by_id("R_3hppta_p").charge = -1
upos.metabolites.get_by_id("R_3hpptcoa_c").charge = -4
upos.metabolites.get_by_id("R_3htd5coa_c").charge = -4
upos.metabolites.get_by_id("R_3httdca_c").charge = -1
upos.metabolites.get_by_id("R_3httdca_e").charge = -1
upos.metabolites.get_by_id("R_3httdca_p").charge = -1
upos.metabolites.get_by_id("R_3hpt_c").charge = -1
upos.metabolites.get_by_id("R_3hpt_e").charge = -1
upos.metabolites.get_by_id("R_3hpt_p").charge = -1
upos.metabolites.get_by_id("R_3hptcoa_c").charge = -4
upos.metabolites.get_by_id("R_3htd58e_c").charge = -1
upos.metabolites.get_by_id("R_3htd58e_e").charge = -1
upos.metabolites.get_by_id("R_3htd58e_p").charge = -1
upos.metabolites.get_by_id("R_3htd58coa_c").charge = -4
upos.metabolites.get_by_id("rbflvrd_c").charge = 0
upos.metabolites.get_by_id("ribflv_c").charge = 0
upos.metabolites.get_by_id("ribflv_e").charge = 0
upos.metabolites.get_by_id("rml1p_c").charge = -2
upos.metabolites.get_by_id("s17bp_c").charge = -4
upos.metabolites.get_by_id("S2hglut_c").charge = -2
upos.metabolites.get_by_id("salc_c").charge = -1
upos.metabolites.get_by_id("salc_e").charge = -1
upos.metabolites.get_by_id("salchs1_c").charge = -5
upos.metabolites.get_by_id("salchs2_c").charge = -6 #Nao mexer
upos.metabolites.get_by_id("salchs2_e").charge = -6
upos.metabolites.get_by_id("salchs2_p").charge = -6
upos.metabolites.get_by_id("salchs4_c").charge = -5
upos.metabolites.get_by_id("salchs4_e").charge = -5
upos.metabolites.get_by_id("salchs4_p").charge = -5
upos.metabolites.get_by_id("salchs2fe_c").charge = -3 #Nao mexer
upos.metabolites.get_by_id("salchs2fe_e").charge = -3
upos.metabolites.get_by_id("salchs2fe_p").charge = -3
upos.metabolites.get_by_id("salchs4fe_c").charge = -2 #Nao mexer
upos.metabolites.get_by_id("salchs4fe_e").charge = -2
upos.metabolites.get_by_id("salchs4fe_p").charge = -2
upos.metabolites.get_by_id("salchsx_c").charge = -5 #Do not change
upos.metabolites.get_by_id("salchsx_e").charge = -5
upos.metabolites.get_by_id("salchsx_p").charge = -5
upos.metabolites.get_by_id("sbt6p_c").charge = -2
upos.metabolites.get_by_id("scl_c").charge = -7 #Kept
upos.metabolites.get_by_id("sdhlam_c").charge = -1
upos.metabolites.get_by_id("serglugly_c").charge = -1
upos.metabolites.get_by_id("serglugly_e").charge = -1
upos.metabolites.get_by_id("ssaltpp_c").charge = -3
upos.metabolites.get_by_id("stfrnB_c").charge = -5
upos.metabolites.get_by_id("stfrnB_e").charge = -5
upos.metabolites.get_by_id("suc6p_c").charge = -2
upos.metabolites.get_by_id("tag1p__D_c").charge = -2
upos.metabolites.get_by_id("tag6p__D_c").charge = -2
upos.metabolites.get_by_id("tagdp__D_c").charge = -4
upos.metabolites.get_by_id("tagur_c").charge = -1
upos.metabolites.get_by_id("tagur_e").charge = -1
upos.metabolites.get_by_id("tamocta_c").charge = -1
upos.metabolites.get_by_id("td2coa_c").charge = -4
upos.metabolites.get_by_id("td_5_8_coa_c").charge = -4
upos.metabolites.get_by_id("td58_2_coa_c").charge = -4
upos.metabolites.get_by_id("tde_2Z_coa_c").charge = -4
upos.metabolites.get_by_id("tdecoa_c").charge = -4
upos.metabolites.get_by_id("tde2coa_c").charge = -4
upos.metabolites.get_by_id("tded5coa_c").charge = -4
upos.metabolites.get_by_id("tded5_2_coa_c").charge = -4
upos.metabolites.get_by_id("tdeACP_c").charge = 0
upos.metabolites.get_by_id("tetscoa_c").charge = -19
upos.metabolites.get_by_id("thf_c").charge = -2
upos.metabolites.get_by_id("thmpp_c").charge = -2
upos.metabolites.get_by_id("tmanur_e").charge = -3
upos.metabolites.get_by_id("tmanur_p").charge = -3
upos.metabolites.get_by_id("tmhexc_c").charge = -1
upos.metabolites.get_by_id("tmrs2eACP_c").charge = -1
upos.metabolites.get_by_id("trnaglu_c").charge = 0
upos.metabolites.get_by_id("tsul_c").charge = -2
upos.metabolites.get_by_id("tsul_e").charge = -2
upos.metabolites.get_by_id("tsul_p").charge = -2
upos.metabolites.get_by_id("tddec2eACP_c").charge = -1
upos.metabolites.get_by_id("tdec2eACP_c").charge = -1
upos.metabolites.get_by_id("ttdceap_c").charge = -1
upos.metabolites.get_by_id("ttdcap_c").charge = -1
upos.metabolites.get_by_id("tton_e").charge = -2
upos.metabolites.get_by_id("tton_p").charge = -2
upos.metabolites.get_by_id("tdeACP_c").charge = -1
upos.metabolites.get_by_id("sbzcoa_c").charge = -5
upos.metabolites.get_by_id("scys__L_c").charge = -1
upos.metabolites.get_by_id("S_gtrdhdlp_c").charge = -1
upos.metabolites.get_by_id("ssaltpp_c").charge = -3
upos.metabolites.get_by_id("uaagmda_c").charge = -4
upos.metabolites.get_by_id("uagmda_c").charge = -4 #Kept
upos.metabolites.get_by_id("uamr_c").charge = -3 
upos.metabolites.get_by_id("udcpdp_c").charge = -3 
upos.metabolites.get_by_id("udcpdp_e").charge = -3
upos.metabolites.get_by_id("udcpp_c").charge = -2 #Kept #OK
upos.metabolites.get_by_id("udcpp_e").charge = -2 #Kept #OK
upos.metabolites.get_by_id("udpacgal_c").charge = -2
upos.metabolites.get_by_id("udpacgal_e").charge = -2
upos.metabolites.get_by_id("udpacgal_p").charge = -2
upos.metabolites.get_by_id("vacc_c").charge = -1
upos.metabolites.get_by_id("vacc_e").charge = -1
upos.metabolites.get_by_id("vacc_p").charge = -1
upos.metabolites.get_by_id("vacccoa_c").charge = -4
upos.metabolites.get_by_id("vacc2coa_c").charge = -4
upos.metabolites.get_by_id("xylan4_c").charge = -1
upos.metabolites.get_by_id("xylan4_e").charge = -1
upos.metabolites.get_by_id("xylan8_e").charge = -2

# %%
upos.metabolites.get_by_id("sulfac_c")
# Out:
# <Metabolite sulfac_c at 0x7fd229a08790>

# %%
upos.reactions.get_by_id("ETHSO3tex")
# Out:
# <Reaction ETHSO3tex at 0x7fd2289eecd0>

# %%
#Replacing duplicated metabolites (Duplication found by MEMOTE)
#Criteria: A: Number of reactions in the model. B: Present in other databases C: Number of model with that metabolite in BiGG. 

# +btoh -1btol
upos.reactions.get_by_id("BTS").add_metabolites({upos.metabolites.get_by_id("btoh_c"): +1})
upos.reactions.get_by_id("BTS").subtract_metabolites({upos.metabolites.get_by_id("1btol_c"): +1})
upos.reactions.get_by_id("BTS_nadph").add_metabolites({upos.metabolites.get_by_id("btoh_c"): +1})
upos.reactions.get_by_id("BTS_nadph").subtract_metabolites({upos.metabolites.get_by_id("1btol_c"): +1})
upos.remove_metabolites([upos.metabolites.get_by_id("1btol_c")])
upos.repair()

# +hkmpp -2h3k5m
upos.reactions.get_by_id("HKM1PP").add_metabolites({upos.metabolites.get_by_id("hkmpp_c"): -1})
upos.reactions.get_by_id("HKM1PP").subtract_metabolites({upos.metabolites.get_by_id("2h3k5m_c"): -1})
upos.reactions.get_by_id("DM1PE").add_metabolites({upos.metabolites.get_by_id("hkmpp_c"): +1})
upos.reactions.get_by_id("DM1PE").subtract_metabolites({upos.metabolites.get_by_id("2h3k5m_c"): +1})
upos.remove_metabolites([upos.metabolites.get_by_id("2h3k5m_c")])
upos.repair()

# +2h3oppan -2h3opp
upos.reactions.get_by_id("GLXCBL").add_metabolites({upos.metabolites.get_by_id("2h3oppan_c"): +1})
upos.reactions.get_by_id("GLXCBL").subtract_metabolites({upos.metabolites.get_by_id("2h3opp_c"): +1})
upos.reactions.get_by_id("GLCRAL_1").add_metabolites({upos.metabolites.get_by_id("2h3oppan_c"): +1})
upos.reactions.get_by_id("GLCRAL_1").subtract_metabolites({upos.metabolites.get_by_id("2h3opp_c"): +1})
upos.reactions.get_by_id("HOXPRx").add_metabolites({upos.metabolites.get_by_id("2h3oppan_c"): +1})
upos.reactions.get_by_id("HOXPRx").subtract_metabolites({upos.metabolites.get_by_id("2h3opp_c"): +1})
upos.remove_metabolites([upos.metabolites.get_by_id("2h3opp_c")])
upos.repair()

# +2hxmp -2hymeph_c
upos.reactions.get_by_id("6PHBG").add_metabolites({upos.metabolites.get_by_id("2hxmp_c"): +1})
upos.reactions.get_by_id("6PHBG").subtract_metabolites({upos.metabolites.get_by_id("2hymeph_c"): +1})
upos.reactions.get_by_id("6PHBG2").add_metabolites({upos.metabolites.get_by_id("2hxmp_c"): +1})
upos.reactions.get_by_id("6PHBG2").subtract_metabolites({upos.metabolites.get_by_id("2hymeph_c"): +1})
upos.remove_metabolites([upos.metabolites.get_by_id("2hymeph_c")])
upos.repair()

# +2kmb -4met2obut
upos.reactions.get_by_id("ARAT").add_metabolites({upos.metabolites.get_by_id("2kmb_c"): -1})
upos.reactions.get_by_id("ARAT").subtract_metabolites({upos.metabolites.get_by_id("4met2obut_c"): -1})
upos.reactions.get_by_id("ARD_1").add_metabolites({upos.metabolites.get_by_id("2kmb_c"): +1})
upos.reactions.get_by_id("ARD_1").subtract_metabolites({upos.metabolites.get_by_id("4met2obut_c"): +1})
upos.remove_metabolites([upos.metabolites.get_by_id("4met2obut_c")])
upos.repair()

# +34dhpha -34dhpacet
upos.reactions.get_by_id("4HOXPACMON").add_metabolites({upos.metabolites.get_by_id("34dhpha_c"): +1})
upos.reactions.get_by_id("4HOXPACMON").subtract_metabolites({upos.metabolites.get_by_id("34dhpacet_c"): +1})
upos.reactions.get_by_id("4HOXPACMOF_1").add_metabolites({upos.metabolites.get_by_id("34dhpha_c"): +1})
upos.reactions.get_by_id("4HOXPACMOF_1").subtract_metabolites({upos.metabolites.get_by_id("34dhpacet_c"): +1})
upos.reactions.get_by_id("34DHPACDO").add_metabolites({upos.metabolites.get_by_id("34dhpha_c"): -1})
upos.reactions.get_by_id("34DHPACDO").subtract_metabolites({upos.metabolites.get_by_id("34dhpacet_c"): -1})
upos.remove_metabolites([upos.metabolites.get_by_id("34dhpacet_c")])
upos.repair()

# -3hbycoa +3hbcoa
upos.reactions.get_by_id("ECOAH1_1").add_metabolites({upos.metabolites.get_by_id("3hbcoa_c"): -1})
upos.reactions.get_by_id("ECOAH1_1").subtract_metabolites({upos.metabolites.get_by_id("3hbycoa_c"): -1})
upos.reactions.get_by_id("HACD1_1").add_metabolites({upos.metabolites.get_by_id("3hbcoa_c"): +1})
upos.reactions.get_by_id("HACD1_1").subtract_metabolites({upos.metabolites.get_by_id("3hbycoa_c"): +1})
upos.remove_metabolites([upos.metabolites.get_by_id("3hbycoa_c")])
upos.repair()

# -hibcoa +3hibutcoa
upos.reactions.get_by_id("HIBHr").add_metabolites({upos.metabolites.get_by_id("3hibutcoa_c"): -1})
upos.reactions.get_by_id("HIBHr").subtract_metabolites({upos.metabolites.get_by_id("hibcoa_c"): -1})
upos.reactions.get_by_id("ECOAH2c").add_metabolites({upos.metabolites.get_by_id("3hibutcoa_c"): +1})
upos.reactions.get_by_id("ECOAH2c").subtract_metabolites({upos.metabolites.get_by_id("hibcoa_c"): +1})
upos.remove_metabolites([upos.metabolites.get_by_id("hibcoa_c")])
upos.repair()

# -5dh4dglc +5d4dglcr
upos.reactions.get_by_id("D4DGCD").add_metabolites({upos.metabolites.get_by_id("5dh4dglc_c"): -1})
upos.reactions.get_by_id("D4DGCD").subtract_metabolites({upos.metabolites.get_by_id("5d4dglcr_c"): -1})
upos.reactions.get_by_id("GLCRAL_1").add_metabolites({upos.metabolites.get_by_id("5dh4dglc_c"): -1})
upos.reactions.get_by_id("GLCRAL_1").subtract_metabolites({upos.metabolites.get_by_id("5d4dglcr_c"): -1})
upos.reactions.get_by_id("GALCTD_1").add_metabolites({upos.metabolites.get_by_id("5dh4dglc_c"): +1})
upos.reactions.get_by_id("GALCTD_1").subtract_metabolites({upos.metabolites.get_by_id("5d4dglcr_c"): +1})
upos.reactions.get_by_id("GLCRD_1").add_metabolites({upos.metabolites.get_by_id("5dh4dglc_c"): +1})
upos.reactions.get_by_id("GLCRD_1").subtract_metabolites({upos.metabolites.get_by_id("5d4dglcr_c"): +1})
upos.remove_metabolites([upos.metabolites.get_by_id("5d4dglcr_c")])
upos.repair()

# -amacald +aacald
upos.reactions.get_by_id("FDMO4_1").add_metabolites({upos.metabolites.get_by_id("aacald_c"): +1})
upos.reactions.get_by_id("FDMO4_1").subtract_metabolites({upos.metabolites.get_by_id("amacald_c"): +1})
upos.reactions.get_by_id("ALDD31_1").add_metabolites({upos.metabolites.get_by_id("aacald_c"): -1})
upos.reactions.get_by_id("ALDD31_1").subtract_metabolites({upos.metabolites.get_by_id("amacald_c"): -1})
upos.remove_metabolites([upos.metabolites.get_by_id("amacald_c")])
upos.repair()

# -abt__L +abt (c)
upos.reactions.get_by_id("ABTt_1").add_metabolites({upos.metabolites.get_by_id("abt_c"): +1})
upos.reactions.get_by_id("ABTt_1").subtract_metabolites({upos.metabolites.get_by_id("abt__L_c"): +1})
upos.reactions.get_by_id("ARABRr").add_metabolites({upos.metabolites.get_by_id("abt_c"): +1})
upos.reactions.get_by_id("ARABRr").subtract_metabolites({upos.metabolites.get_by_id("abt__L_c"): +1})
upos.remove_metabolites([upos.metabolites.get_by_id("abt__L_c")])
upos.repair()

# -abt__L +abt (e)
upos.reactions.get_by_id("ABTt_1").add_metabolites({upos.metabolites.get_by_id("abt_e"): -1})
upos.reactions.get_by_id("ABTt_1").subtract_metabolites({upos.metabolites.get_by_id("abt__L_e"): -1})
upos.reactions.get_by_id("EX_abt__L_e").add_metabolites({upos.metabolites.get_by_id("abt_e"): -1})
upos.reactions.get_by_id("EX_abt__L_e").subtract_metabolites({upos.metabolites.get_by_id("abt__L_e"): -1})
upos.remove_metabolites([upos.metabolites.get_by_id("abt__L_e")])
upos.repair()

# -acamoxm +nal2a6o
upos.reactions.get_by_id("ADPTA").add_metabolites({upos.metabolites.get_by_id("nal2a6o_c"): +1})
upos.reactions.get_by_id("ADPTA").subtract_metabolites({upos.metabolites.get_by_id("acamoxm_c"): +1})
upos.reactions.get_by_id("APTA1i").add_metabolites({upos.metabolites.get_by_id("nal2a6o_c"): -1})
upos.reactions.get_by_id("APTA1i").subtract_metabolites({upos.metabolites.get_by_id("acamoxm_c"): -1})
upos.reactions.get_by_id("APATi").add_metabolites({upos.metabolites.get_by_id("nal2a6o_c"): +1})
upos.reactions.get_by_id("APATi").subtract_metabolites({upos.metabolites.get_by_id("acamoxm_c"): +1})
upos.remove_metabolites([upos.metabolites.get_by_id("acamoxm_c")])
upos.repair()

# -trans_dd2coa +dd2coa (c)
upos.reactions.get_by_id("ACOAD5_1").add_metabolites({upos.metabolites.get_by_id("dd2coa_c"): +1})
upos.reactions.get_by_id("ACOAD5_1").subtract_metabolites({upos.metabolites.get_by_id("trans_dd2coa_c"): +1})
upos.reactions.get_by_id("ECOAH5_1").add_metabolites({upos.metabolites.get_by_id("dd2coa_c"): +1})
upos.reactions.get_by_id("ECOAH5_1").subtract_metabolites({upos.metabolites.get_by_id("trans_dd2coa_c"): +1})
upos.remove_metabolites([upos.metabolites.get_by_id("trans_dd2coa_c")])
upos.repair()

# -shcl +dscl
upos.reactions.get_by_id("UPP3MT_2").add_metabolites({upos.metabolites.get_by_id("dscl_c"): +1})
upos.reactions.get_by_id("UPP3MT_2").subtract_metabolites({upos.metabolites.get_by_id("shcl_c"): +1})
upos.reactions.get_by_id("SHCHD2_1").add_metabolites({upos.metabolites.get_by_id("dscl_c"): -1})
upos.reactions.get_by_id("SHCHD2_1").subtract_metabolites({upos.metabolites.get_by_id("shcl_c"): -1})
upos.remove_metabolites([upos.metabolites.get_by_id("shcl_c")])
upos.repair()

# eths_p does not exist. Creating it
M_eths_p = cobra.Metabolite(id="eths_p", compartment="C_p", name="Ethanesulfonate C2H5O3S", formula="C2H5O3S", charge=-1)
upos.add_metabolites([M_eths_p])

#  +eths -ethso3 (c)
upos.reactions.get_by_id("FDMO3").add_metabolites({upos.metabolites.get_by_id("eths_c"): -1})
upos.reactions.get_by_id("FDMO3").subtract_metabolites({upos.metabolites.get_by_id("ethso3_c"): -1})
upos.reactions.get_by_id("ETHSO3abcpp").add_metabolites({upos.metabolites.get_by_id("eths_c"): +1})
upos.reactions.get_by_id("ETHSO3abcpp").subtract_metabolites({upos.metabolites.get_by_id("ethso3_c"): +1})
upos.remove_metabolites([upos.metabolites.get_by_id("ethso3_c")])
upos.repair()

# +eths -ethso3 (e)
upos.reactions.get_by_id("EX_ethso3_e").add_metabolites({upos.metabolites.get_by_id("eths_e"): -1})
upos.reactions.get_by_id("EX_ethso3_e").subtract_metabolites({upos.metabolites.get_by_id("ethso3_e"): -1})
upos.reactions.get_by_id("ETHSO3tex").add_metabolites({upos.metabolites.get_by_id("eths_e"): -1})
upos.reactions.get_by_id("ETHSO3tex").subtract_metabolites({upos.metabolites.get_by_id("ethso3_e"): -1})
upos.remove_metabolites([upos.metabolites.get_by_id("ethso3_e")])
upos.repair()

# +eths -ethso3 (p)
upos.reactions.get_by_id("ETHSO3abcpp").add_metabolites({upos.metabolites.get_by_id("eths_p"): -1})
upos.reactions.get_by_id("ETHSO3abcpp").subtract_metabolites({upos.metabolites.get_by_id("ethso3_p"): -1})
upos.reactions.get_by_id("ETHSO3tex").add_metabolites({upos.metabolites.get_by_id("eths_p"): +1})
upos.reactions.get_by_id("ETHSO3tex").subtract_metabolites({upos.metabolites.get_by_id("ethso3_p"): +1})
upos.remove_metabolites([upos.metabolites.get_by_id("ethso3_p")])
upos.repair()

# -galctr__D +galct__D (e)
upos.reactions.get_by_id("GALCTRt2").add_metabolites({upos.metabolites.get_by_id("galct__D_e"): -1})
upos.reactions.get_by_id("GALCTRt2").subtract_metabolites({upos.metabolites.get_by_id("galctr__D_e"): -1})
upos.reactions.get_by_id("EX_galctr__D_e").add_metabolites({upos.metabolites.get_by_id("galct__D_e"): -1})
upos.reactions.get_by_id("EX_galctr__D_e").subtract_metabolites({upos.metabolites.get_by_id("galctr__D_e"): -1})
upos.remove_metabolites([upos.metabolites.get_by_id("galctr__D_e")])
upos.repair()

# -galctr__D +galct__D (c)
upos.reactions.get_by_id("GALCTRt2").add_metabolites({upos.metabolites.get_by_id("galct__D_c"): +1})
upos.reactions.get_by_id("GALCTRt2").subtract_metabolites({upos.metabolites.get_by_id("galctr__D_c"): +1})
upos.reactions.get_by_id("GALCTD_1").add_metabolites({upos.metabolites.get_by_id("galct__D_c"): -1})
upos.reactions.get_by_id("GALCTD_1").subtract_metabolites({upos.metabolites.get_by_id("galctr__D_c"): -1})
upos.remove_metabolites([upos.metabolites.get_by_id("galctr__D_c")])
upos.repair()

# -glcn__D +glcn (c)
upos.reactions.get_by_id("GLCNt2ir").add_metabolites({upos.metabolites.get_by_id("glcn_c"): +1})
upos.reactions.get_by_id("GLCNt2ir").subtract_metabolites({upos.metabolites.get_by_id("glcn__D_c"): +1})
upos.reactions.get_by_id("GNKr").add_metabolites({upos.metabolites.get_by_id("glcn_c"): -1})
upos.reactions.get_by_id("GNKr").subtract_metabolites({upos.metabolites.get_by_id("glcn__D_c"): -1})
upos.remove_metabolites([upos.metabolites.get_by_id("glcn__D_c")])
upos.repair()

# -glcn__D +glcn (e)
upos.reactions.get_by_id("GLCNt2ir").add_metabolites({upos.metabolites.get_by_id("glcn_e"): -1})
upos.reactions.get_by_id("GLCNt2ir").subtract_metabolites({upos.metabolites.get_by_id("glcn__D_e"): -1})
upos.reactions.get_by_id("EX_glcn__D_e").add_metabolites({upos.metabolites.get_by_id("glcn_e"): -1})
upos.reactions.get_by_id("EX_glcn__D_e").subtract_metabolites({upos.metabolites.get_by_id("glcn__D_e"): -1})
upos.remove_metabolites([upos.metabolites.get_by_id("glcn__D_e")])
upos.repair()

# istnt_p does not exist. Creating it
M_istnt_p = cobra.Metabolite(id="istnt_p", compartment="C_p", name="Isethionate C2H5O4S", formula="C2H5O4S", charge = -1)
upos.add_metabolites([M_istnt_p])

# -isetac +istnt (c)
upos.reactions.get_by_id("FDMO").add_metabolites({upos.metabolites.get_by_id("istnt_c"): -1})
upos.reactions.get_by_id("FDMO").subtract_metabolites({upos.metabolites.get_by_id("isetac_c"): -1})
upos.reactions.get_by_id("ISETACabcpp").add_metabolites({upos.metabolites.get_by_id("istnt_c"): +1})
upos.reactions.get_by_id("ISETACabcpp").subtract_metabolites({upos.metabolites.get_by_id("isetac_c"): +1})
upos.remove_metabolites([upos.metabolites.get_by_id("isetac_c")])
upos.repair()

# -isetac +istnt (e)
upos.reactions.get_by_id("EX_isetac_e").add_metabolites({upos.metabolites.get_by_id("istnt_e"): -1})
upos.reactions.get_by_id("EX_isetac_e").subtract_metabolites({upos.metabolites.get_by_id("isetac_e"): -1})
upos.reactions.get_by_id("ISETACtex").add_metabolites({upos.metabolites.get_by_id("istnt_e"): -1})
upos.reactions.get_by_id("ISETACtex").subtract_metabolites({upos.metabolites.get_by_id("isetac_e"): -1})
upos.remove_metabolites([upos.metabolites.get_by_id("isetac_e")])
upos.repair()

# -isetac +istnt (p)
upos.reactions.get_by_id("ISETACabcpp").add_metabolites({upos.metabolites.get_by_id("istnt_p"): -1})
upos.reactions.get_by_id("ISETACabcpp").subtract_metabolites({upos.metabolites.get_by_id("isetac_p"): -1})
upos.reactions.get_by_id("ISETACtex").add_metabolites({upos.metabolites.get_by_id("istnt_p"): +1})
upos.reactions.get_by_id("ISETACtex").subtract_metabolites({upos.metabolites.get_by_id("isetac_p"): +1})
upos.remove_metabolites([upos.metabolites.get_by_id("isetac_p")])
upos.repair()

# metox_p does not exist. Creating it
M_metox_p = cobra.Metabolite(id="metox_p", compartment="C_p", name="L Methionine S oxide C5H11NO3S", formula="C5H11NO3S", charge = 0)
upos.add_metabolites([M_metox_p])

# -metsox_S__L +metox (c)
upos.reactions.get_by_id("METSOXR1").add_metabolites({upos.metabolites.get_by_id("metox_c"): -1})
upos.reactions.get_by_id("METSOXR1").subtract_metabolites({upos.metabolites.get_by_id("metsox_S__L_c"): -1})
upos.reactions.get_by_id("METOX1s").add_metabolites({upos.metabolites.get_by_id("metox_c"): +1})
upos.reactions.get_by_id("METOX1s").subtract_metabolites({upos.metabolites.get_by_id("metsox_S__L_c"): +1})
upos.reactions.get_by_id("METSOX1abc").add_metabolites({upos.metabolites.get_by_id("metox_c"): +1})
upos.reactions.get_by_id("METSOX1abc").subtract_metabolites({upos.metabolites.get_by_id("metsox_S__L_c"): +1})
upos.reactions.get_by_id("METSOX1abcpp").add_metabolites({upos.metabolites.get_by_id("metox_c"): +1})
upos.reactions.get_by_id("METSOX1abcpp").subtract_metabolites({upos.metabolites.get_by_id("metsox_S__L_c"): +1})
upos.remove_metabolites([upos.metabolites.get_by_id("metsox_S__L_c")])
upos.repair()

# -metsox_S__L +metox (e)
upos.reactions.get_by_id("EX_metsox_S__L_e").add_metabolites({upos.metabolites.get_by_id("metox_e"): -1})
upos.reactions.get_by_id("EX_metsox_S__L_e").subtract_metabolites({upos.metabolites.get_by_id("metsox_S__L_e"): -1})
upos.reactions.get_by_id("METSOX1abc").add_metabolites({upos.metabolites.get_by_id("metox_e"): -1})
upos.reactions.get_by_id("METSOX1abc").subtract_metabolites({upos.metabolites.get_by_id("metsox_S__L_e"): -1})
upos.reactions.get_by_id("METSOX1tex").add_metabolites({upos.metabolites.get_by_id("metox_e"): -1})
upos.reactions.get_by_id("METSOX1tex").subtract_metabolites({upos.metabolites.get_by_id("metsox_S__L_e"): -1})
upos.remove_metabolites([upos.metabolites.get_by_id("metsox_S__L_e")])

# -metsox_S__L +metox (p)
upos.reactions.get_by_id("METSOX1abcpp").add_metabolites({upos.metabolites.get_by_id("metox_p"): -1})
upos.reactions.get_by_id("METSOX1abcpp").subtract_metabolites({upos.metabolites.get_by_id("metsox_S__L_p"): -1})
upos.reactions.get_by_id("METSOX1tex").add_metabolites({upos.metabolites.get_by_id("metox_p"): +1})
upos.reactions.get_by_id("METSOX1tex").subtract_metabolites({upos.metabolites.get_by_id("metsox_S__L_p"): +1})
upos.remove_metabolites([upos.metabolites.get_by_id("metsox_S__L_p")])


# -orn__L +orn (c)
upos.reactions.get_by_id("ORNCD_1").add_metabolites({upos.metabolites.get_by_id("orn_c"): -1})
upos.reactions.get_by_id("ORNCD_1").subtract_metabolites({upos.metabolites.get_by_id("orn__L_c"): -1})
upos.reactions.get_by_id("ORNt2").add_metabolites({upos.metabolites.get_by_id("orn_c"): +1})
upos.reactions.get_by_id("ORNt2").subtract_metabolites({upos.metabolites.get_by_id("orn__L_c"): +1})
upos.reactions.get_by_id("ARGORNt3").add_metabolites({upos.metabolites.get_by_id("orn_c"): -1})
upos.reactions.get_by_id("ARGORNt3").subtract_metabolites({upos.metabolites.get_by_id("orn__L_c"): -1})
upos.reactions.get_by_id("ACODA_1").add_metabolites({upos.metabolites.get_by_id("orn_c"): +1})
upos.reactions.get_by_id("ACODA_1").subtract_metabolites({upos.metabolites.get_by_id("orn__L_c"): +1})
upos.reactions.get_by_id("ARGN_1").add_metabolites({upos.metabolites.get_by_id("orn_c"): +1})
upos.reactions.get_by_id("ARGN_1").subtract_metabolites({upos.metabolites.get_by_id("orn__L_c"): +1})
upos.reactions.get_by_id("ORNTAC_1").add_metabolites({upos.metabolites.get_by_id("orn_c"): +1})
upos.reactions.get_by_id("ORNTAC_1").subtract_metabolites({upos.metabolites.get_by_id("orn__L_c"): +1})
upos.reactions.get_by_id("ORNTA_1").add_metabolites({upos.metabolites.get_by_id("orn_c"): -1})
upos.reactions.get_by_id("ORNTA_1").subtract_metabolites({upos.metabolites.get_by_id("orn__L_c"): -1})
upos.reactions.get_by_id("OCBT_1").add_metabolites({upos.metabolites.get_by_id("orn_c"): -1})
upos.reactions.get_by_id("OCBT_1").subtract_metabolites({upos.metabolites.get_by_id("orn__L_c"): -1})
upos.remove_metabolites([upos.metabolites.get_by_id("orn__L_c")])
upos.repair()

# -orn__L +orn (e)
upos.reactions.get_by_id("ORNt2").add_metabolites({upos.metabolites.get_by_id("orn_e"): -1})
upos.reactions.get_by_id("ORNt2").subtract_metabolites({upos.metabolites.get_by_id("orn__L_e"): -1})
upos.reactions.get_by_id("EX_orn__L_e").add_metabolites({upos.metabolites.get_by_id("orn_e"): -1})
upos.reactions.get_by_id("EX_orn__L_e").subtract_metabolites({upos.metabolites.get_by_id("orn__L_e"): -1})
upos.reactions.get_by_id("ARGORNt3").add_metabolites({upos.metabolites.get_by_id("orn_e"): +1})
upos.reactions.get_by_id("ARGORNt3").subtract_metabolites({upos.metabolites.get_by_id("orn__L_e"): +1})
upos.remove_metabolites([upos.metabolites.get_by_id("orn__L_e")])
upos.repair()

# -srch +scl
upos.reactions.get_by_id("SHCHF_2").add_metabolites({upos.metabolites.get_by_id("scl_c"): -1})
upos.reactions.get_by_id("SHCHF_2").subtract_metabolites({upos.metabolites.get_by_id("srch_c"): -1})
upos.reactions.get_by_id("SHCHD2_1").add_metabolites({upos.metabolites.get_by_id("scl_c"): +1})
upos.reactions.get_by_id("SHCHD2_1").subtract_metabolites({upos.metabolites.get_by_id("srch_c"): +1})
upos.remove_metabolites([upos.metabolites.get_by_id("srch_c")])
upos.repair()

# +stcoa_c -strcoa_c
upos.reactions.get_by_id("G3POA_BS").add_metabolites({upos.metabolites.get_by_id("stcoa_c"): -3})
upos.reactions.get_by_id("G3POA_BS").subtract_metabolites({upos.metabolites.get_by_id("strcoa_c"): -3})
upos.reactions.get_by_id("FACOAL180_2").add_metabolites({upos.metabolites.get_by_id("stcoa_c"): +1})
upos.reactions.get_by_id("FACOAL180_2").subtract_metabolites({upos.metabolites.get_by_id("strcoa_c"): +1})
upos.reactions.get_by_id("AGPATr_BS").add_metabolites({upos.metabolites.get_by_id("stcoa_c"): -3})
upos.reactions.get_by_id("AGPATr_BS").subtract_metabolites({upos.metabolites.get_by_id("strcoa_c"): -3})
upos.remove_metabolites([upos.metabolites.get_by_id("strcoa_c")])
upos.repair()

# sula_p does not exist. Creating it
M_sula_p = cobra.Metabolite(id="sula_p", compartment="C_p", name="Sulfoacetate C2H2O5S", formula="C2H2O5S", charge = -2)
upos.add_metabolites([M_sula_p])
upos.repair()

# -sulfac +sula (c)
upos.reactions.get_by_id("FDMO6").add_metabolites({upos.metabolites.get_by_id("sula_c"): -1})
upos.reactions.get_by_id("FDMO6").subtract_metabolites({upos.metabolites.get_by_id("sulfac_c"): -1})
upos.reactions.get_by_id("SULFACabcpp").add_metabolites({upos.metabolites.get_by_id("sula_c"): +1})
upos.reactions.get_by_id("SULFACabcpp").subtract_metabolites({upos.metabolites.get_by_id("sulfac_c"): +1})
upos.remove_metabolites([upos.metabolites.get_by_id("sulfac_c")])
upos.repair()

# -sulfac +sula (e)
upos.reactions.get_by_id("EX_sulfac_e").add_metabolites({upos.metabolites.get_by_id("sula_e"): -1})
upos.reactions.get_by_id("EX_sulfac_e").subtract_metabolites({upos.metabolites.get_by_id("sulfac_e"): -1})
upos.reactions.get_by_id("SULFACtex").add_metabolites({upos.metabolites.get_by_id("sula_e"): -1})
upos.reactions.get_by_id("SULFACtex").subtract_metabolites({upos.metabolites.get_by_id("sulfac_e"): -1})
upos.remove_metabolites([upos.metabolites.get_by_id("sulfac_e")])
upos.repair()

# -sulfac +sula (p)
upos.reactions.get_by_id("SULFACabcpp").add_metabolites({upos.metabolites.get_by_id("sula_p"): -1})
upos.reactions.get_by_id("SULFACabcpp").subtract_metabolites({upos.metabolites.get_by_id("sulfac_p"): -1})
upos.reactions.get_by_id("SULFACtex").add_metabolites({upos.metabolites.get_by_id("sula_p"): +1})
upos.reactions.get_by_id("SULFACtex").subtract_metabolites({upos.metabolites.get_by_id("sulfac_p"): +1})
upos.remove_metabolites([upos.metabolites.get_by_id("sulfac_p")])
upos.repair()

# %%
#Fixing Stechiometry
#G3POA_BS and AGPATr_BS were fixed manually because it's easier. Values obtained from MetaNetX
upos.reactions.get_by_id("23CTI1").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.reactions.get_by_id("2H3MBDH").subtract_metabolites({upos.metabolites.get_by_id("h_c"): -1})
upos.reactions.get_by_id("2H3MBDH").add_metabolites({upos.metabolites.get_by_id("h2_c"): -1})
upos.reactions.get_by_id("2H3MBDH").add_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.reactions.get_by_id("2H3MPDH").add_metabolites({upos.metabolites.get_by_id("h_c"): -1})
upos.reactions.get_by_id("2H3MPDH").add_metabolites({upos.metabolites.get_by_id("h2_c"): +0.5})
upos.reactions.get_by_id("3HAD141").subtract_metabolites({upos.metabolites.get_by_id("h_c"): -1})
upos.reactions.get_by_id("AACLAM").add_metabolites({upos.metabolites.get_by_id("h_c"): +2})
upos.reactions.get_by_id("AALDH").add_metabolites({upos.metabolites.get_by_id("h_c"): -1})
upos.reactions.get_by_id("ACOAD10f").subtract_metabolites({upos.metabolites.get_by_id("h_c"): -2})
upos.reactions.get_by_id("ACOAD11f").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +2})
upos.reactions.get_by_id("ACOAD12f").subtract_metabolites({upos.metabolites.get_by_id("h_c"): -2})
upos.reactions.get_by_id("ACOAD13f").subtract_metabolites({upos.metabolites.get_by_id("h_c"): -2})
upos.reactions.get_by_id("ACOAD14f").subtract_metabolites({upos.metabolites.get_by_id("h_c"): -2})
upos.reactions.get_by_id("ACOAD15f").subtract_metabolites({upos.metabolites.get_by_id("h_c"): -2})
upos.reactions.get_by_id("ACOAD16f").subtract_metabolites({upos.metabolites.get_by_id("h_c"): -2})
upos.reactions.get_by_id("ACOAD17f").subtract_metabolites({upos.metabolites.get_by_id("h_c"): -2})
upos.reactions.get_by_id("ACOAD18f").subtract_metabolites({upos.metabolites.get_by_id("h_c"): -2})
upos.reactions.get_by_id("ACOAD19f").subtract_metabolites({upos.metabolites.get_by_id("h_c"): -2})
upos.reactions.get_by_id("ACOAD20f").subtract_metabolites({upos.metabolites.get_by_id("h_c"): -2})
upos.reactions.get_by_id("ACOAD21f").subtract_metabolites({upos.metabolites.get_by_id("h_c"): -2})
upos.reactions.get_by_id("ACOAD24f").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.reactions.get_by_id("ACOAD25f").subtract_metabolites({upos.metabolites.get_by_id("h_c"): -2})
upos.reactions.get_by_id("ACOAD29f").subtract_metabolites({upos.metabolites.get_by_id("h_c"): -2})
upos.reactions.get_by_id("ACOAD30f").subtract_metabolites({upos.metabolites.get_by_id("h_c"): -1})
upos.reactions.get_by_id("ACOAD31f").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +2})
upos.reactions.get_by_id("ACOAD34f").subtract_metabolites({upos.metabolites.get_by_id("h_c"): -2})
upos.reactions.get_by_id("ACOAM").add_metabolites({upos.metabolites.get_by_id("h_c"): -2})
upos.reactions.get_by_id("AHMMPS").subtract_metabolites({upos.metabolites.get_by_id("h_c"): -2})
upos.reactions.get_by_id("AHMMPS").add_metabolites({upos.metabolites.get_by_id("h2_c"): -1})
upos.reactions.get_by_id("AIRSK").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +2})
upos.reactions.get_by_id("AMMQT8").add_metabolites({upos.metabolites.get_by_id("h2_c"): -1})
upos.reactions.get_by_id("AMMQT8").add_metabolites({upos.metabolites.get_by_id("h_c"): +2})
upos.reactions.get_by_id("AMMQLT8_2").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +2})
upos.reactions.get_by_id("AMMQLT8_2").add_metabolites({upos.metabolites.get_by_id("h2_c"): +1})
upos.reactions.get_by_id("ARAT").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.reactions.get_by_id("ARD_1").add_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.reactions.get_by_id("AT_MBD2").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.reactions.get_by_id("BCOALIG").subtract_metabolites({upos.metabolites.get_by_id("h_c"): -4})
upos.reactions.get_by_id("BKDA2").add_metabolites({upos.metabolites.get_by_id("h_c"): -1})
upos.reactions.get_by_id("BKDC").subtract_metabolites({upos.metabolites.get_by_id("h_c"): -1})
upos.reactions.get_by_id("BMNMSHS").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +2})
upos.reactions.get_by_id("BSCT").subtract_metabolites({upos.metabolites.get_by_id("h_c"): -4})
upos.reactions.get_by_id("BTS2").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +2})
upos.reactions.get_by_id("BTS2").add_metabolites({upos.metabolites.get_by_id("h2_c"): +1})
upos.reactions.get_by_id("CITDAPPS").add_metabolites({upos.metabolites.get_by_id("o2_c"): -0.5})
upos.reactions.get_by_id("CMCBTFR1").subtract_metabolites({upos.metabolites.get_by_id("h_c"): 2})
upos.reactions.get_by_id("CMCBTFR2").subtract_metabolites({upos.metabolites.get_by_id("h_c"): 2})
upos.reactions.get_by_id("CMCBTFU").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.reactions.get_by_id("CPP3O1").add_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.reactions.get_by_id("CPP3O1").add_metabolites({upos.metabolites.get_by_id("h2_c"): -0.5})
upos.reactions.get_by_id("CYP1").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.reactions.get_by_id("CYP1").add_metabolites({upos.metabolites.get_by_id("h_c"): -1})
upos.reactions.get_by_id("DAAD3").subtract_metabolites({upos.metabolites.get_by_id("h_c"): -2})
upos.reactions.get_by_id("DAAD7").add_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.reactions.get_by_id("DAAD11").subtract_metabolites({upos.metabolites.get_by_id("h_c"): -2})
upos.reactions.get_by_id("DAAD12").subtract_metabolites({upos.metabolites.get_by_id("h_c"): -2})
upos.reactions.get_by_id("DACL").add_metabolites({upos.metabolites.get_by_id("h2_c"): -1.5})
upos.reactions.get_by_id("DACL").add_metabolites({upos.metabolites.get_by_id("h_c"): +3})
upos.reactions.get_by_id("DAPAL").subtract_metabolites({upos.metabolites.get_by_id("h_c"): -1})
upos.reactions.get_by_id("DB4PS").add_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.reactions.get_by_id("DGUO").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +4})
upos.reactions.get_by_id("DGUO").add_metabolites({upos.metabolites.get_by_id("h2_c"): +2})
upos.reactions.get_by_id("DHNAOT").add_metabolites({upos.metabolites.get_by_id("h2_c"): +1})
upos.reactions.get_by_id("DHNAOT").add_metabolites({upos.metabolites.get_by_id("h_c"): -2})
upos.reactions.get_by_id("DHBD").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.reactions.get_by_id("DHBS").subtract_metabolites({upos.metabolites.get_by_id("h_c"): -1})
upos.reactions.get_by_id("DHBZS2H").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.reactions.get_by_id("DHBZS3H").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.reactions.get_by_id("DKMD2K").add_metabolites({upos.metabolites.get_by_id("h_c"): +2})
upos.reactions.get_by_id("DM1PE").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.reactions.get_by_id("DMBI").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.reactions.get_by_id("DMBI").add_metabolites({upos.metabolites.get_by_id("h_c"): -1})
upos.reactions.get_by_id("DTBTST").add_metabolites({upos.metabolites.get_by_id("h_c"): +2})
upos.reactions.get_by_id("DTBTST").add_metabolites({upos.metabolites.get_by_id("h2_c"): -1})
upos.reactions.get_by_id("DTBTt").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.reactions.get_by_id("ECOAH2c").subtract_metabolites({upos.metabolites.get_by_id("h_c"): -1})
upos.reactions.get_by_id("ENTCS").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.reactions.get_by_id("ENTERES").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +2})
upos.reactions.get_by_id("ENTERES2").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +2})
upos.reactions.get_by_id("ENTERGLCT2").add_metabolites({upos.metabolites.get_by_id("h_c"): +5})
upos.reactions.get_by_id("FADE30").subtract_metabolites({upos.metabolites.get_by_id("h_c"): -1})
upos.reactions.get_by_id("FBACS").subtract_metabolites({upos.metabolites.get_by_id("h_c"): -1})
upos.reactions.get_by_id("FDMO7").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +4})
upos.reactions.get_by_id("FECPP3O").add_metabolites({upos.metabolites.get_by_id("h_c"): -1})
upos.reactions.get_by_id("FECPP3O").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +4})
upos.reactions.get_by_id("FECPP3O").add_metabolites({upos.metabolites.get_by_id("h2_c"): +2.5})
upos.reactions.get_by_id("FEDHBZS3R1").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +2})
upos.reactions.get_by_id("FEDHBZS3R2").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +2})
upos.reactions.get_by_id("FEDHBZS3R3").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +2})
upos.reactions.get_by_id("FE3DHBZS3R").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +2})
upos.reactions.get_by_id("FEENTERES").subtract_metabolites({upos.metabolites.get_by_id("h_c"): -1})
upos.reactions.get_by_id("FNOR").add_metabolites({upos.metabolites.get_by_id("h_c"): -2})
upos.reactions.get_by_id("FNOR").add_metabolites({upos.metabolites.get_by_id("h2_c"): +1})
upos.reactions.get_by_id("FORGLUIH2").add_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.reactions.get_by_id("FPRA").add_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.reactions.get_by_id("FPRA").add_metabolites({upos.metabolites.get_by_id("h2_c"): -0.5})
upos.reactions.get_by_id("FRDO").add_metabolites({upos.metabolites.get_by_id("h2_c"): -0.5})
upos.reactions.get_by_id("FRDO").add_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.reactions.get_by_id("FTR").add_metabolites({upos.metabolites.get_by_id("h_c"): -2})
upos.reactions.get_by_id("FTR").add_metabolites({upos.metabolites.get_by_id("h2_c"): +1})
upos.reactions.get_by_id("GCDH").add_metabolites({upos.metabolites.get_by_id("h_c"): -1})
upos.reactions.get_by_id("GCDH").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.reactions.get_by_id("GCDH").add_metabolites({upos.metabolites.get_by_id("h2_c"): +1})
upos.reactions.get_by_id("GLMS_syn").add_metabolites({upos.metabolites.get_by_id("h2_c"): +1})
upos.reactions.get_by_id("GLMS_syn").add_metabolites({upos.metabolites.get_by_id("h_c"): -2})
upos.reactions.get_by_id("GLYCOLDHpp").subtract_metabolites({upos.metabolites.get_by_id("h_c"): -1})
upos.reactions.get_by_id("GLYCYSabc").add_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.reactions.get_by_id("GLYCYSAP").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.reactions.get_by_id("GLYLEUAP").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.reactions.get_by_id("GLYLEUtr").add_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.reactions.get_by_id("GLYTYRAP").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.reactions.get_by_id("GLYTYRabc").add_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.reactions.get_by_id("GLYPHEAP").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.reactions.get_by_id("GLYPHEtr").add_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.reactions.get_by_id("GLUFT").add_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.reactions.get_by_id("GULNLR").add_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.reactions.get_by_id("GULNLR").subtract_metabolites({upos.metabolites.get_by_id("nad_c"): -1})
upos.reactions.get_by_id("GULNLR").subtract_metabolites({upos.metabolites.get_by_id("nadh_c"): +1})
upos.reactions.get_by_id("H2CD").add_metabolites({upos.metabolites.get_by_id("h2_c"): -0.5})
upos.reactions.get_by_id("H2CD").add_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.reactions.get_by_id("H2CT").add_metabolites({upos.metabolites.get_by_id("h_c"): -4})
upos.reactions.get_by_id("H2CT").add_metabolites({upos.metabolites.get_by_id("h2_c"): +2})
upos.reactions.get_by_id("HDAD").add_metabolites({upos.metabolites.get_by_id("h2_c"): -2})
upos.reactions.get_by_id("HDAD").add_metabolites({upos.metabolites.get_by_id("h_c"): +4})
upos.reactions.get_by_id("HDECH").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +2})
upos.reactions.get_by_id("HDECH").add_metabolites({upos.metabolites.get_by_id("h2_c"): +1})
upos.reactions.get_by_id("HIBHr").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.reactions.get_by_id("HKM1PP").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.reactions.get_by_id("HPCOR").subtract_metabolites({upos.metabolites.get_by_id("h_c"): -1})
upos.reactions.get_by_id("IBHH").add_metabolites({upos.metabolites.get_by_id("h_c"): -2})
upos.reactions.get_by_id("IBHH").add_metabolites({upos.metabolites.get_by_id("h2_c"): +1})
upos.reactions.get_by_id("ICCT").add_metabolites({upos.metabolites.get_by_id("h_c"): +3})
upos.reactions.get_by_id("ICCT").add_metabolites({upos.metabolites.get_by_id("h2_c"): -1.5})
upos.reactions.get_by_id("LIPATPT").subtract_metabolites({upos.metabolites.get_by_id("h_c"): -1})
upos.reactions.get_by_id("LIPATPT_2").subtract_metabolites({upos.metabolites.get_by_id("h_c"): -1})
upos.reactions.get_by_id("MB2CFO").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +2})
upos.reactions.get_by_id("M2BCT").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +2})
upos.reactions.get_by_id("MAN6Gpts").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +3})
upos.reactions.get_by_id("MB2CFO").add_metabolites({upos.metabolites.get_by_id("h_c"): +2})
upos.reactions.get_by_id("MCBTFR1").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +2})
upos.reactions.get_by_id("MCBTFR2").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +2})
upos.reactions.get_by_id("MECDPDH3_syn").add_metabolites({upos.metabolites.get_by_id("h2_c"): +1})
upos.reactions.get_by_id("MECDPDH3_syn").add_metabolites({upos.metabolites.get_by_id("h_c"): -2})
upos.reactions.get_by_id("MECDPDH").subtract_metabolites({upos.metabolites.get_by_id("h_c"): -1})
upos.reactions.get_by_id("MECDPDH").add_metabolites({upos.metabolites.get_by_id("h2_c"): -1})
upos.reactions.get_by_id("MECDPDH").add_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.reactions.get_by_id("MVNOR").add_metabolites({upos.metabolites.get_by_id("h_c"): -2})
upos.reactions.get_by_id("MVNOR").add_metabolites({upos.metabolites.get_by_id("h2_c"): +1})
upos.reactions.get_by_id("NACGS").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.reactions.get_by_id("NAR_syn").add_metabolites({upos.metabolites.get_by_id("h2_c"): +1})
upos.reactions.get_by_id("NAR_syn").add_metabolites({upos.metabolites.get_by_id("h_c"): -2})
upos.reactions.get_by_id("NFORGLUAH").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.reactions.get_by_id("NFORGLUAH2").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.reactions.get_by_id("NMO").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +4})
upos.reactions.get_by_id("NMO").add_metabolites({upos.metabolites.get_by_id("h2_c"): +2})
upos.reactions.get_by_id("NOR_syn_1").add_metabolites({upos.metabolites.get_by_id("h2_c"): +3})
upos.reactions.get_by_id("NOR_syn_1").add_metabolites({upos.metabolites.get_by_id("h_c"): -6})
upos.reactions.get_by_id("NOS3").add_metabolites({upos.metabolites.get_by_id("h_c"): -1})
upos.reactions.get_by_id("NOS3").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +3})
upos.reactions.get_by_id("NOS3").add_metabolites({upos.metabolites.get_by_id("h2_c"): +2})
upos.reactions.get_by_id("OCDOR").add_metabolites({upos.metabolites.get_by_id("h_c"): -1})
upos.reactions.get_by_id("OOR3r").add_metabolites({upos.metabolites.get_by_id("h_c"): -1})
upos.reactions.get_by_id("OOR3r").add_metabolites({upos.metabolites.get_by_id("h2_c"): +0.5})
upos.reactions.get_by_id("P9DH").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +4})
upos.reactions.get_by_id("P9DH").add_metabolites({upos.metabolites.get_by_id("h2_c"): +2})
upos.reactions.get_by_id("PEAOpp").subtract_metabolites({upos.metabolites.get_by_id("h_c"): -1})
upos.reactions.get_by_id("PHACA").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +2})
upos.reactions.get_by_id("PHACA").add_metabolites({upos.metabolites.get_by_id("h2_c"): +1})
upos.reactions.get_by_id("PHDCATA").add_metabolites({upos.metabolites.get_by_id("h2_c"): -0.5})
upos.reactions.get_by_id("PHDCATA").add_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.reactions.get_by_id("PHER").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +2})
upos.reactions.get_by_id("PHET").subtract_metabolites({upos.metabolites.get_by_id("h_c"): -2})
upos.reactions.get_by_id("POR_syn").add_metabolites({upos.metabolites.get_by_id("h_c"): +2})
upos.reactions.get_by_id("POR_syn").add_metabolites({upos.metabolites.get_by_id("h2_c"): -1})
upos.reactions.get_by_id("PREPTHS").add_metabolites({upos.metabolites.get_by_id("h_c"): -1})
upos.reactions.get_by_id("PROR").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.reactions.get_by_id("PSP_1").add_metabolites({upos.metabolites.get_by_id("h_c"): +2})
upos.reactions.get_by_id("PSTA").add_metabolites({upos.metabolites.get_by_id("h_c"): -2})
upos.reactions.get_by_id("SALCHS1H").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.reactions.get_by_id("SALCHS2H").add_metabolites({upos.metabolites.get_by_id("h2_c"): -5.5})
upos.reactions.get_by_id("SALCHS2H").add_metabolites({upos.metabolites.get_by_id("h_c"): +4})
upos.reactions.get_by_id("SALCHS2FER1").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +2})
upos.reactions.get_by_id("SALCHS2FER2").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +2})
upos.reactions.get_by_id("SALCHS2FER3").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +2})
upos.reactions.get_by_id("SALCHS4FEHpp").add_metabolites({upos.metabolites.get_by_id("h_p"): +1})
upos.reactions.get_by_id("SALCHS4FEHpp").add_metabolites({upos.metabolites.get_by_id("h2_p"): +0.5})
upos.reactions.get_by_id("SALCHS4FER1").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +2})
upos.reactions.get_by_id("SALCHS4FER2").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +2})
upos.reactions.get_by_id("SALCHS4FER3").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +2})
upos.reactions.get_by_id("SALCHS4Hpp").add_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.reactions.get_by_id("SALCHS4Hpp").add_metabolites({upos.metabolites.get_by_id("h2_c"): +0.5})
upos.reactions.get_by_id("SHCHF_2").add_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.reactions.get_by_id("SEAHCYSHYD").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.reactions.get_by_id("SEAHCYSHYD_1").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.reactions.get_by_id("SORD_D").subtract_metabolites({upos.metabolites.get_by_id("h_c"): -2})
upos.reactions.get_by_id("SUCD2").subtract_metabolites({upos.metabolites.get_by_id("h_c"): -2})
upos.reactions.get_by_id("SUCD2").add_metabolites({upos.metabolites.get_by_id("h2_c"): -1})
upos.reactions.get_by_id("SUCBZT1").subtract_metabolites({upos.metabolites.get_by_id("h_c"): -4})
upos.reactions.get_by_id("SULR_syn").add_metabolites({upos.metabolites.get_by_id("h2_c"): +3})
upos.reactions.get_by_id("SULR_syn").add_metabolites({upos.metabolites.get_by_id("h_c"): -6})
upos.reactions.get_by_id("TAG1PK").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +2})
upos.reactions.get_by_id("TAGabc").add_metabolites({upos.metabolites.get_by_id("h_c"): -1})
upos.reactions.get_by_id("THIH").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +2})
upos.reactions.get_by_id("THIH").add_metabolites({upos.metabolites.get_by_id("h2_c"): +1})
upos.reactions.get_by_id("THZSN").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +2})
upos.reactions.get_by_id("THZSN").add_metabolites({upos.metabolites.get_by_id("h2_c"): +1})
upos.reactions.get_by_id("TTONR1pp").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +2})
upos.reactions.get_by_id("TTONR2pp").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +2})
upos.reactions.get_by_id("UACCpts").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +3})
upos.reactions.get_by_id("UNK2").add_metabolites({upos.metabolites.get_by_id("h_c"): +2})
upos.reactions.get_by_id("UNK2").add_metabolites({upos.metabolites.get_by_id("h2_c"): -1})
upos.reactions.get_by_id("UPP3MT_2").subtract_metabolites({upos.metabolites.get_by_id("h_c"): +1})
upos.repair()

# %%
#Writting intermediate network
sbml = "/homes/brauerei/natasha/miniconda3/lib/python3.9/site-packages/carveme/data/generated/universe_grampos.fixedN.xml"
print(sbml)
cobra.io.write_sbml_model(upos,sbml)
# Out:
# /homes/brauerei/natasha/miniconda3/lib/python3.9/site-packages/carveme/data/generated/universe_grampos.fixedN.xml

# %%
upos.reactions.get_by_id("AGM4PCPpp").check_mass_balance()
# Out:
# {}

# %%
upos.reactions.get_by_id("ETHSO3abcpp")
# Out:
# <Reaction ETHSO3abcpp at 0x7fd2289eed00>

# %%
upos.metabolites.get_by_id("prealgac_M2_p").charge
# Out:
# -5

# %%
upos.metabolites.get_by_id("man6p_c")
# Out:
# <Metabolite man6p_c at 0x7fd229bb86d0>
